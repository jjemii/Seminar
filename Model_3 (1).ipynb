# %% [markdown]
# # Text Summarization
#
# In this notebook I will write summaries with the help of my Seq2Seq model in Summarizer.py.
#
# The model works impressively well in the end!

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# !mkdir -p drive
# !google-drive-ocamlfuse drive
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 144328 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.22-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.22-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.22-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !pip install tensorflow==1.15
# !pip install "tensorflow_hub>=0.6.0"
# !pip3 install tensorflow_text==1.15
# Out:
# Collecting tensorflow==1.15
#   Downloading https://files.pythonhosted.org/packages/3f/98/5a99af92fb911d7a88a0005ad55005f35b4c1ba8d75fba02df726cd936e6/tensorflow-1.15.0-cp36-cp36m-manylinux2010_x86_64.whl (412.3MB)
#      |████████████████████████████████| 412.3MB 36kB/s
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 41.6MB/s
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.2.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.8.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (3.2.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.1.2)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.12.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.12.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.34.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.18.5)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 54.4MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.29.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (3.10.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.9.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.0.8)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (47.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.2.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (1.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.1.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=5a12e94c1c468775d480c07dffad61dc058927517060d0889e431c6a04bc92cc
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.10.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# Installing collected packages: tensorflow-estimator, gast, tensorboard, tensorflow
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
#   Found existing installation: tensorflow 2.2.0
#     Uninstalling tensorflow-2.2.0:
#       Successfully uninstalled tensorflow-2.2.0
# Successfully installed gast-0.2.2 tensorboard-1.15.0 tensorflow-1.15.0 tensorflow-estimator-1.15.1
# Requirement already satisfied: tensorflow_hub>=0.6.0 in /usr/local/lib/python3.6/dist-packages (0.8.0)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow_hub>=0.6.0) (1.18.5)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow_hub>=0.6.0) (1.12.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow_hub>=0.6.0) (3.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorflow_hub>=0.6.0) (47.1.1)
# Collecting tensorflow_text==1.15
#   Downloading https://files.pythonhosted.org/packages/44/61/9569353ce3efb8ee818d0d2e2f67afbb19e1e3a56eba3a93986e92949003/tensorflow_text-1.15.0-cp36-cp36m-manylinux1_x86_64.whl (9.1MB)
#      |████████████████████████████████| 9.1MB 4.3MB/s
# Requirement already satisfied: tensorflow<1.16,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow_text==1.15) (1.15.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (3.2.1)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (1.15.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (0.9.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (0.34.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (1.18.5)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (1.12.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (3.10.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (1.0.8)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (0.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (1.1.2)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (1.15.1)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (0.2.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (1.29.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (1.12.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (47.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (3.2.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (1.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow<1.16,>=1.15.0->tensorflow_text==1.15) (3.1.0)
# Installing collected packages: tensorflow-text
# Successfully installed tensorflow-text-1.15.0

# %%
import os

import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
from collections import Counter


#import Summarizer
#import summarizer_data_utils
#import summarizer_model_utils

# %%
print(tf.__version__)
# Out:
# 1.15.0

# %% [markdown]
# ## Helpers (Google Connect, Summurizer)

# %% [markdown]
# ### Summurizer

# %% [markdown]
# #### summarizer_model_utils

# %%
import numpy as np

from nltk.translate.bleu_score import sentence_bleu


def minibatches(inputs, targets, minibatch_size):
    """batch generator. yields x and y batch.
    """
    x_batch, y_batch = [], []
    for inp, tgt in zip(inputs, targets):
        if len(x_batch) == minibatch_size and len(y_batch) == minibatch_size:
            yield x_batch, y_batch
            x_batch, y_batch = [], []
        x_batch.append(inp)
        y_batch.append(tgt)

    if len(x_batch) != 0:
        for inp, tgt in zip(inputs, targets):
            if len(x_batch) != minibatch_size:
                x_batch.append(inp)
                y_batch.append(tgt)
            else:
                break
        yield x_batch, y_batch


def pad_sequences(sequences, pad_tok, tail=True):
    """Pads the sentences, so that all sentences in a batch have the same length.
    """

    max_length = max(len(x) for x in sequences)

    sequence_padded, sequence_length = [], []

    for seq in sequences:
        seq = list(seq)
        if tail:
            seq_ = seq[:max_length] + [pad_tok] * max(max_length - len(seq), 0)
        else:
            seq_ = [pad_tok] * max(max_length - len(seq), 0) + seq[:max_length]

        sequence_padded += [seq_]
        sequence_length += [min(len(seq), max_length)]

    return sequence_padded, sequence_length


def sample_results(preds, ind2word, word2ind, converted_summaries, converted_texts, use_bleu=False):
    """Plots the actual text and summary and the corresponding created summary.
    takes care of whether beam search or greedy decoder was used.
    """
    beam = False

    if len(np.array(preds).shape) == 4:
        beam = True

    '''Bleu score is not used correctly here, but serves as reference.
    '''
    if use_bleu:
        bleu_scores = []

    for pred, summary, text, seq_length in zip(preds[0],
                                               converted_summaries,
                                               converted_texts,
                                               [len(inds) for inds in converted_summaries]):
        print('\n\n\n', 100 * '-')
        if beam:
            actual_text = [ind2word[word] for word in text if
                           word != word2ind["<SOS>"] and word != word2ind["<EOS>"]]
            actual_summary = [ind2word[word] for word in summary if
                              word != word2ind['<EOS>'] and word != word2ind['<SOS>']]

            created_summary = []
            for word in pred:
                if word[0] != word2ind['<SOS>'] and word[0] != word2ind['<EOS>']:
                    created_summary.append(ind2word[word[0]])
                    continue
                else:
                    continue

            print('Actual Text:\n{}\n'.format(' '.join(actual_text)))
            print('Actual Summary:\n{}\n'.format(' '.join(actual_summary)))
            print('Created Summary:\n{}\n'.format(' '.join(created_summary)))
            if use_bleu:
                bleu_score = sentence_bleu([actual_summary], created_summary)
                bleu_scores.append(bleu_score)
                print('Bleu-score:', bleu_score)

            print()


        else:
            actual_text = [ind2word[word] for word in text if
                           word != word2ind["<SOS>"] and word != word2ind["<EOS>"]]
            actual_summary = [ind2word[word] for word in summary if
                              word != word2ind['<EOS>'] and word != word2ind['<SOS>']]
            created_summary = [ind2word[word] for word in pred if
                               word != word2ind['<EOS>'] and word != word2ind['<SOS>']]

            print('Actual Text:\n{}\n'.format(' '.join(actual_text)))
            print('Actual Summary:\n{}\n'.format(' '.join(actual_summary)))
            print('Created Summary:\n{}\n'.format(' '.join(created_summary)))
            if use_bleu:
                bleu_score = sentence_bleu([actual_summary], created_summary)
                bleu_scores.append(bleu_score)
                print('Bleu-score:', bleu_score)

    if use_bleu:
        bleu_score = np.mean(bleu_scores)
        print('\n\n\nTotal Bleu Score:', bleu_score)


def reset_graph(seed=97):
    """helper function to reset the default graph. this often
       comes handy when using jupyter noteboooks.
    """
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# %% [markdown]
# #### summarizer_data_utils

# %%
import os
import time
import re
import html
from collections import Counter

import nltk
import numpy as np


def preprocess_sentence(text, keep_most=False):
    """
    Helper function to remove html, unneccessary spaces and punctuation.
    Args:
        text: String.
        keep_most: Boolean. depending if True or False, we either
                   keep only letters and numbers or also other characters.
    Returns:
        processed text.
    """
    text = text.lower()
    text = fixup(text)
    text = re.sub(r"<br />", " ", text)
    if keep_most:
        text = re.sub(r"[^a-z0-9%!?.,:()/]", " ", text)
    else:
        text = re.sub(r"[^a-z0-9]", " ", text)
    text = re.sub(r"    ", " ", text)
    text = re.sub(r"   ", " ", text)
    text = re.sub(r"  ", " ", text)
    text = text.strip()
    return text


def fixup(x):
    re1 = re.compile(r'  +')
    x = x.replace('#39;', "'").replace('amp;', '&').replace('#146;', "'").replace(
        'nbsp;', ' ').replace('#36;', '$').replace('\\n', "\n").replace('\n\n', "\n").replace('\n\n\n', "\n").replace('quot;', "'").replace(
        '<br />', "\n").replace('\\"', '"').replace('<unk>', 'u_n').replace(' @.@ ', '.').replace(
        ' @-@ ', '-').replace('\\', ' \\ ')
    return re1.sub(' ', html.unescape(x))


def preprocess(text, keep_most=False):
    """
    Splits the text into sentences, preprocesses
       and tokenizes each sentence.
    Args:
        text: String. multiple sentences.
        keep_most: Boolean. depending if True or False, we either
                   keep only letters and numbers or also other characters.
    Returns:
        preprocessed and tokenized text.
    """
    tokenized = []
    for sentence in nltk.sent_tokenize(text):
        sentence = preprocess_sentence(sentence, keep_most)
        sentence = nltk.word_tokenize(sentence)
        for token in sentence:
            tokenized.append(token)

    return tokenized


def preprocess_texts_and_summaries(texts,
                                   summaries,
                                   keep_most=False):
    """iterates given list of texts and given list of summaries and tokenizes every
       review using the tokenize_review() function.
       apart from that we count up all the words in the texts and summaries.
       returns: - processed texts
                - processed summaries
                - array containing all the unique words together with their counts
                  sorted by counts.
    """

    start_time = time.time()
    processed_texts = []
    processed_summaries = []
    words = []

    for text in texts:
        text = preprocess(text, keep_most)
        for word in text:
            words.append(word)
        processed_texts.append(text)
    for summary in summaries:
        summary = preprocess(summary, keep_most)
        for word in summary:
            words.append(word)

        processed_summaries.append(summary)
    words_counted = Counter(words).most_common()
    print('Processing Time: ', time.time() - start_time)

    return processed_texts, processed_summaries, words_counted


def create_word_inds_dicts(words_counted,
                           specials=None,
                           min_occurences=0):
    """ creates lookup dicts from word to index and back.
        returns the lookup dicts and an array of words that were not used,
        due to rare occurence.
    """
    missing_words = []
    word2ind = {}
    ind2word = {}
    i = 0

    if specials is not None:
        for sp in specials:
            word2ind[sp] = i
            ind2word[i] = sp
            i += 1

    for (word, count) in words_counted:
        if count >= min_occurences:
            word2ind[word] = i
            ind2word[i] = word
            i += 1
        else:
            missing_words.append(word)

    return word2ind, ind2word, missing_words


def convert_sentence(review, word2ind):
    """ converts the given sent to int values corresponding to the given word2ind"""
    inds = []
    unknown_words = []

    for word in review:
        if word in word2ind.keys():
            inds.append(int(word2ind[word]))
        else:
            inds.append(int(word2ind['<UNK>']))
            unknown_words.append(word)

    return inds, unknown_words


def convert_to_inds(input, word2ind, eos=False, sos=False):
    converted_input = []
    all_unknown_words = set()

    for inp in input:
        converted_inp, unknown_words = convert_sentence(inp, word2ind)
        if eos:
            converted_inp.append(word2ind['<EOS>'])
        if sos:
            converted_inp.insert(0, word2ind['<SOS>'])
        converted_input.append(converted_inp)
        all_unknown_words.update(unknown_words)

    return converted_input, all_unknown_words


def convert_inds_to_text(inds, ind2word, preprocess=False):
    """ convert the given indexes back to text """
    words = [ind2word[word] for word in inds]
    return words


def load_pretrained_embeddings(path):
    """loads pretrained embeddings. stores each embedding in a
       dictionary with its corresponding word
    """
    embeddings = {}
    with open(path, 'r', encoding='utf-8') as f:
        for line in f:
            values = line.split(' ')
            word = values[0]
            embedding_vector = np.array(values[1:], dtype='float32')
            embeddings[word] = embedding_vector
    return embeddings


def create_and_save_embedding_matrix(word2ind,
                                     pretrained_embeddings_path,
                                     save_path,
                                     embedding_dim=300):
    """creates embedding matrix for each word in word2ind. if that words is in
       pretrained_embeddings, that vector is used. otherwise initialized
       randomly.
    """
    pretrained_embeddings = load_pretrained_embeddings(pretrained_embeddings_path)
    embedding_matrix = np.zeros((len(word2ind), embedding_dim), dtype=np.float32)
    for word, i in word2ind.items():
        if word in pretrained_embeddings.keys():
            embedding_matrix[i] = pretrained_embeddings[word]
        else:
            embedding = np.array(np.random.uniform(-1.0, 1.0, embedding_dim))
            embedding_matrix[i] = embedding
    if not os.path.exists(os.path.dirname(save_path)):
        os.makedirs(os.path.dirname(save_path))
    np.save(save_path, embedding_matrix)
    return np.array(embedding_matrix)

# %% [markdown]
# #### Summarizer

# %%
import os
import numpy as np

import tensorflow as tf
from tensorflow.python.layers.core import Dense

#import summarizer_model_utils


class Summarizer:

    def __init__(self,
                 word2ind,
                 ind2word,
                 save_path,
                 mode='TRAIN',
                 num_layers_encoder=1,
                 num_layers_decoder=1,
                 embedding_dim=300,
                 rnn_size_encoder=256,
                 rnn_size_decoder=256,
                 learning_rate=0.001,
                 learning_rate_decay=0.9,
                 learning_rate_decay_steps=100,
                 max_lr=0.01,
                 keep_probability=0.8,
                 batch_size=64,
                 beam_width=10,
                 epochs=20,
                 eos="<EOS>",
                 sos="<SOS>",
                 pad='<PAD>',
                 clip=5,
                 inference_targets=False,
                 pretrained_embeddings_path=None,
                 summary_dir=None,
                 use_cyclic_lr=False):
        """
        Args:
            word2ind: lookup dict from word to index.
            ind2word: lookup dict from index to word.
            save_path: path to save the tf model to in the end.
            mode: String. 'TRAIN' or 'INFER'. depending on which mode we use
                  a different graph is created.
            num_layers_encoder: Float. Number of encoder layers. defaults to 1.
            num_layers_decoder: Float. Number of decoder layers. defaults to 1.
            embedding_dim: dimension of the embedding vectors in the embedding matrix.
                           every word has a embedding_dim 'long' vector.
            rnn_size_encoder: Integer. number of hidden units in encoder. defaults to 256.
            rnn_size_decoder: Integer. number of hidden units in decoder. defaults to 256.
            learning_rate: Float.
            learning_rate_decay: only if exponential learning rate is used.
            learning_rate_decay_steps: Integer.
            max_lr: only used if cyclic learning rate is used.
            keep_probability: Float.
            batch_size: Integer. Size of minibatches.
            beam_width: Integer. Only used in inference, for Beam Search.('INFER'-mode)
            epochs: Integer. Number of times the training is conducted
                    on the whole training data.
            eos: EndOfSentence tag.
            sos: StartOfSentence tag.
            pad: Padding tag.
            clip: Value to clip the gradients to in training process.
            inference_targets:
            pretrained_embeddings_path: Path to pretrained embeddings. Has to be .npy
            summary_dir: Directory the summaries are written to for tensorboard.
            use_cyclic_lr: Boolean.
        """

        self.word2ind = word2ind
        self.ind2word = ind2word
        self.vocab_size = len(word2ind)
        self.num_layers_encoder = num_layers_encoder
        self.num_layers_decoder = num_layers_decoder
        self.rnn_size_encoder = rnn_size_encoder
        self.rnn_size_decoder = rnn_size_decoder
        self.save_path = save_path
        self.embedding_dim = embedding_dim
        self.mode = mode.upper()
        self.learning_rate = learning_rate
        self.learning_rate_decay = learning_rate_decay
        self.learning_rate_decay_steps = learning_rate_decay_steps
        self.keep_probability = keep_probability
        self.batch_size = batch_size
        self.beam_width = beam_width
        self.eos = eos
        self.sos = sos
        self.clip = clip
        self.pad = pad
        self.epochs = epochs
        self.inference_targets = inference_targets
        self.pretrained_embeddings_path = pretrained_embeddings_path
        self.use_cyclic_lr = use_cyclic_lr
        self.max_lr = max_lr
        self.summary_dir = summary_dir

    def build_graph(self):
        self.add_placeholders()
        self.add_embeddings()
        self.add_lookup_ops()
        self.initialize_session()
        self.add_seq2seq()
        self.saver = tf.train.Saver()
        print('Graph built.')

    def add_placeholders(self):
        self.ids_1 = tf.placeholder(tf.int32,
                                    shape=[None, None],
                                    name='ids_source')
        self.ids_2 = tf.placeholder(tf.int32,
                                    shape=[None, None],
                                    name='ids_target')
        self.sequence_lengths_1 = tf.placeholder(tf.int32,
                                                 shape=[None],
                                                 name='sequence_length_source')
        self.sequence_lengths_2 = tf.placeholder(tf.int32,
                                                 shape=[None],
                                                 name='sequence_length_target')
        self.maximum_iterations = tf.reduce_max(self.sequence_lengths_2,
                                                name='max_dec_len')

    def create_word_embedding(self, embed_name, vocab_size, embed_dim):
        """Creates embedding matrix in given shape - [vocab_size, embed_dim].
        """
        embedding = tf.get_variable(embed_name,
                                    shape=[vocab_size, embed_dim],
                                    dtype=tf.float32)
        return embedding

    def add_embeddings(self):
        """Creates the embedding matrix. In case path to pretrained embeddings is given,
           that embedding is loaded. Otherwise created.
        """
        if self.pretrained_embeddings_path is not None:
            self.embedding = tf.Variable(np.load(self.pretrained_embeddings_path),
                                         name='embedding')
            print('Loaded pretrained embeddings.')
        else:
            self.embedding = self.create_word_embedding('embedding',
                                                        self.vocab_size,
                                                        self.embedding_dim)

    def add_lookup_ops(self):
        """Additional lookup operation for both source embedding and target embedding matrix.
        """
        self.word_embeddings_1 = tf.nn.embedding_lookup(self.embedding,
                                                        self.ids_1,
                                                        name='word_embeddings_1')
        self.word_embeddings_2 = tf.nn.embedding_lookup(self.embedding,
                                                        self.ids_2,
                                                        name='word_embeddings_2')

    def make_rnn_cell(self, rnn_size, keep_probability):
        """Creates LSTM cell wrapped with dropout.
        """
        cell = tf.nn.rnn_cell.LSTMCell(rnn_size)
        cell = tf.nn.rnn_cell.DropoutWrapper(cell, input_keep_prob=keep_probability)
        return cell

    def make_attention_cell(self, dec_cell, rnn_size, enc_output, lengths, alignment_history=False):
        """Wraps the given cell with Bahdanau Attention.
        """
        attention_mechanism = tf.contrib.seq2seq.BahdanauAttention(num_units=rnn_size,
                                                                   memory=enc_output,
                                                                   memory_sequence_length=lengths,
                                                                   name='BahdanauAttention')

        return tf.contrib.seq2seq.AttentionWrapper(cell=dec_cell,
                                                   attention_mechanism=attention_mechanism,
                                                   attention_layer_size=None,
                                                   output_attention=False,
                                                   alignment_history=alignment_history)

    def triangular_lr(self, current_step):
        """cyclic learning rate - exponential range."""
        step_size = self.learning_rate_decay_steps
        base_lr = self.learning_rate
        max_lr = self.max_lr

        cycle = tf.floor(1 + current_step / (2 * step_size))
        x = tf.abs(current_step / step_size - 2 * cycle + 1)
        lr = base_lr + (max_lr - base_lr) * tf.maximum(0.0, tf.cast((1.0 - x), dtype=tf.float32)) * (0.99999 ** tf.cast(
            current_step,
            dtype=tf.float32))
        return lr


    def add_seq2seq(self):
        """Creates the sequence to sequence architecture."""
        with tf.variable_scope('dynamic_seq2seq', dtype=tf.float32):
            # Encoder
            encoder_outputs, encoder_state = self.build_encoder()

            # Decoder
            logits, sample_id, final_context_state = self.build_decoder(encoder_outputs,
                                                                        encoder_state)
            if self.mode == 'TRAIN':

                # Loss
                loss = self.compute_loss(logits)
                self.train_loss = loss
                self.eval_loss = loss
                self.global_step = tf.Variable(0, trainable=False)


                # cyclic learning rate
                if self.use_cyclic_lr:
                    self.learning_rate = self.triangular_lr(self.global_step)

                # exponential learning rate
                else:
                    self.learning_rate = tf.train.exponential_decay(
                        self.learning_rate,
                        self.global_step,
                        decay_steps=self.learning_rate_decay_steps,
                        decay_rate=self.learning_rate_decay,
                        staircase=True)

                # Optimizer
                opt = tf.train.AdamOptimizer(self.learning_rate)


                # Gradients
                if self.clip > 0:
                    grads, vs = zip(*opt.compute_gradients(self.train_loss))
                    grads, _ = tf.clip_by_global_norm(grads, self.clip)
                    self.train_op = opt.apply_gradients(zip(grads, vs),
                                                        global_step=self.global_step)
                else:
                    self.train_op = opt.minimize(self.train_loss,
                                                 global_step=self.global_step)



            elif self.mode == 'INFER':
                loss = None
                self.infer_logits, _, self.final_context_state, self.sample_id = logits, loss, final_context_state, sample_id
                self.sample_words = self.sample_id

    def build_encoder(self):
        """The encoder. Bidirectional LSTM."""

        with tf.variable_scope("encoder"):
            fw_cell = self.make_rnn_cell(self.rnn_size_encoder // 2, self.keep_probability)
            bw_cell = self.make_rnn_cell(self.rnn_size_encoder // 2, self.keep_probability)

            for _ in range(self.num_layers_encoder):
                (out_fw, out_bw), (state_fw, state_bw) = tf.nn.bidirectional_dynamic_rnn(
                    cell_fw=fw_cell,
                    cell_bw=bw_cell,
                    inputs=self.word_embeddings_1,
                    sequence_length=self.sequence_lengths_1,
                    dtype=tf.float32)
                encoder_outputs = tf.concat((out_fw, out_bw), -1)

            bi_state_c = tf.concat((state_fw.c, state_bw.c), -1)
            bi_state_h = tf.concat((state_fw.h, state_bw.h), -1)
            bi_lstm_state = tf.nn.rnn_cell.LSTMStateTuple(c=bi_state_c, h=bi_state_h)
            encoder_state = tuple([bi_lstm_state] * self.num_layers_encoder)

            return encoder_outputs, encoder_state


    def build_decoder(self, encoder_outputs, encoder_state):

        sos_id_2 = tf.cast(self.word2ind[self.sos], tf.int32)
        eos_id_2 = tf.cast(self.word2ind[self.eos], tf.int32)
        self.output_layer = Dense(self.vocab_size, name='output_projection')

        # Decoder.
        with tf.variable_scope("decoder") as decoder_scope:

            cell, decoder_initial_state = self.build_decoder_cell(
                encoder_outputs,
                encoder_state,
                self.sequence_lengths_1)

            # Train
            if self.mode != 'INFER':

                helper = tf.contrib.seq2seq.ScheduledEmbeddingTrainingHelper(
                    inputs=self.word_embeddings_2,
                    sequence_length=self.sequence_lengths_2,
                    embedding=self.embedding,
                    sampling_probability=0.5,
                    time_major=False)

                # Decoder
                my_decoder = tf.contrib.seq2seq.BasicDecoder(cell,
                                                             helper,
                                                             decoder_initial_state,
                                                             output_layer=self.output_layer)

                # Dynamic decoding
                outputs, final_context_state, _ = tf.contrib.seq2seq.dynamic_decode(
                    my_decoder,
                    output_time_major=False,
                    maximum_iterations=self.maximum_iterations,
                    swap_memory=False,
                    impute_finished=True,
                    scope=decoder_scope
                )

                sample_id = outputs.sample_id
                logits = outputs.rnn_output


            # Inference
            else:
                start_tokens = tf.fill([self.batch_size], sos_id_2)
                end_token = eos_id_2

                # beam search
                if self.beam_width > 0:
                    my_decoder = tf.contrib.seq2seq.BeamSearchDecoder(
                        cell=cell,
                        embedding=self.embedding,
                        start_tokens=start_tokens,
                        end_token=end_token,
                        initial_state=decoder_initial_state,
                        beam_width=self.beam_width,
                        output_layer=self.output_layer,
                    )

                # greedy
                else:
                    helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(self.embedding,
                                                                      start_tokens,
                                                                      end_token)

                    my_decoder = tf.contrib.seq2seq.BasicDecoder(cell,
                                                                 helper,
                                                                 decoder_initial_state,
                                                                 output_layer=self.output_layer)
                if self.inference_targets:
                    maximum_iterations = self.maximum_iterations
                else:
                    maximum_iterations = None

                # Dynamic decoding
                outputs, final_context_state, _ = tf.contrib.seq2seq.dynamic_decode(
                    my_decoder,
                    maximum_iterations=maximum_iterations,
                    output_time_major=False,
                    impute_finished=False,
                    swap_memory=False,
                    scope=decoder_scope)

                if self.beam_width > 0:
                    logits = tf.no_op()
                    sample_id = outputs.predicted_ids
                else:
                    logits = outputs.rnn_output
                    sample_id = outputs.sample_id

        return logits, sample_id, final_context_state

    def build_decoder_cell(self, encoder_outputs, encoder_state,
                           sequence_lengths_1):
        """Builds the attention decoder cell. If mode is inference performs tiling
           Passes last encoder state.
        """

        memory = encoder_outputs

        if self.mode == 'INFER' and self.beam_width > 0:
            memory = tf.contrib.seq2seq.tile_batch(memory,
                                                   multiplier=self.beam_width)
            encoder_state = tf.contrib.seq2seq.tile_batch(encoder_state,
                                                          multiplier=self.beam_width)
            sequence_lengths_1 = tf.contrib.seq2seq.tile_batch(sequence_lengths_1,
                                                               multiplier=self.beam_width)
            batch_size = self.batch_size * self.beam_width

        else:
            batch_size = self.batch_size

        # MY APPROACH
        if self.num_layers_decoder is not None:
            lstm_cell = tf.nn.rnn_cell.MultiRNNCell(
                [self.make_rnn_cell(self.rnn_size_decoder, self.keep_probability) for _ in
                 range(self.num_layers_decoder)])

        else:
            lstm_cell = self.make_rnn_cell(self.rnn_size_decoder, self.keep_probability)

        # attention cell
        cell = self.make_attention_cell(lstm_cell,
                                        self.rnn_size_decoder,
                                        memory,
                                        sequence_lengths_1)

        decoder_initial_state = cell.zero_state(batch_size, tf.float32).clone(cell_state=encoder_state)

        return cell, decoder_initial_state


    def compute_loss(self, logits):
        """Compute the loss during optimization."""
        target_output = self.ids_2
        max_time = self.maximum_iterations

        target_weights = tf.sequence_mask(self.sequence_lengths_2,
                                          max_time,
                                          dtype=tf.float32,
                                          name='mask')

        loss = tf.contrib.seq2seq.sequence_loss(logits=logits,
                                                targets=target_output,
                                                weights=target_weights,
                                                average_across_timesteps=True,
                                                average_across_batch=True, )
        return loss


    def train(self,
              inputs,
              targets,
              restore_path=None,
              validation_inputs=None,
              validation_targets=None):
        """Performs the training process. Runs training step in every epoch.
           Shuffles input data before every epoch.
           Optionally: - add tensorboard summaries.
                       - restoring previous model and retraining on top.
                       - evaluation step.
        """
        assert len(inputs) == len(targets)

        if self.summary_dir is not None:
            self.add_summary()

        self.initialize_session()
        if restore_path is not None:
            self.restore_session(restore_path)

        best_score = np.inf
        nepoch_no_imprv = 0

        inputs = np.array(inputs)
        targets = np.array(targets)

        for epoch in range(self.epochs + 1):
            print('-------------------- Epoch {} of {} --------------------'.format(epoch,
                                                                                    self.epochs))

            # shuffle the input data before every epoch.
            shuffle_indices = np.random.permutation(len(inputs))
            inputs = inputs[shuffle_indices]
            targets = targets[shuffle_indices]

            # run training epoch
            score = self.run_epoch(inputs, targets, epoch)

            # evaluate model
            if validation_inputs is not None and validation_targets is not None:
                self.run_evaluate(validation_inputs, validation_targets, epoch)


            #if not os.path.exists(self.save_path):
            #        os.makedirs(self.save_path)
            #    self.saver.save(self.sess, self.save_path)
                
            if score <= best_score:
                nepoch_no_imprv = 0
                if not os.path.exists(self.save_path):
                    os.makedirs(self.save_path)
                self.saver.save(self.sess, self.save_path)
                best_score = score
                print("--- new best score ---\n\n")
            else:
                # warm up epochs for the model
                if epoch > 10:
                    nepoch_no_imprv += 1
                # early stopping
                if nepoch_no_imprv >= 5:
                    print("- early stopping {} epochs without improvement".format(nepoch_no_imprv))
                    break

    def infer(self, inputs, restore_path, targets=None):
        """Runs inference process. No training takes place.
           Returns the predicted ids for every sentence.
        """
        self.initialize_session()
        self.restore_session(restore_path)

        prediction_ids = []
        if targets is not None:
            feed, _, sequence_lengths_2 = self.get_feed_dict(inputs, trgts=targets)
        else:
            feed, _ = self.get_feed_dict(inputs)

        infer_logits, s_ids = self.sess.run([self.infer_logits, self.sample_words], feed_dict=feed)
        prediction_ids.append(s_ids)

        # for (inps, trgts) in summarizer_model_utils.minibatches(inputs, targets, self.batch_size):
        #     feed, _, sequence_lengths= self.get_feed_dict(inps, trgts=trgts)
        #     infer_logits, s_ids = self.sess.run([self.infer_logits, self.sample_words], feed_dict = feed)
        #     prediction_ids.append(s_ids)

        return prediction_ids

    def run_epoch(self, inputs, targets, epoch):
        """Runs a single epoch.
           Returns the average loss value on the epoch."""
        batch_size = self.batch_size
        nbatches = (len(inputs) + batch_size - 1) // batch_size
        losses = []

        for i, (inps, trgts) in enumerate(minibatches(inputs,
                                                                             targets,
                                                                             batch_size)):
            if inps is not None and trgts is not None:
                fd, sl, s2 = self.get_feed_dict(inps,
                                                trgts=trgts)

                if i % 10 == 0 and self.summary_dir is not None:
                    _, train_loss, training_summ = self.sess.run([self.train_op,
                                                                  self.train_loss,
                                                                  self.training_summary],
                                                                 feed_dict=fd)
                    self.training_writer.add_summary(training_summ, epoch*nbatches + i)

                else:
                    _, train_loss = self.sess.run([self.train_op, self.train_loss],
                                                  feed_dict=fd)

                if i % 2 == 0 or i == (nbatches - 1):
                    print('Iteration: {} of {}\ttrain_loss: {:.4f}'.format(i, nbatches - 1, train_loss))
                losses.append(train_loss)

            else:
                print('Minibatch empty.')
                continue

        avg_loss = self.sess.run(tf.reduce_mean(losses))
        print('Average Score for this Epoch: {}'.format(avg_loss))

        return avg_loss

    def run_evaluate(self, inputs, targets, epoch):
        """Runs evaluation on validation inputs and targets.
        Optionally: - writes summary to Tensorboard.
        """
        if self.summary_dir is not None:
            eval_losses = []
            for inps, trgts in minibatches(inputs, targets, self.batch_size):
                fd, sl, s2 = self.get_feed_dict(inps, trgts)
                eval_loss = self.sess.run([self.eval_loss], feed_dict=fd)
                eval_losses.append(eval_loss)

            avg_eval_loss = self.sess.run(tf.reduce_mean(eval_losses))

            print('Eval_loss: {}\n'.format(avg_eval_loss))
            eval_summ = self.sess.run([self.eval_summary], feed_dict=fd)
           # self.eval_writer.add_summary(eval_summ, epoch)

        else:
            eval_losses = []
            for inps, trgts in minibatches(inputs, targets, self.batch_size):
                fd, sl, s2 = self.get_feed_dict(inps, trgts)
                eval_loss = self.sess.run([self.eval_loss], feed_dict=fd)
                eval_losses.append(eval_loss)

            avg_eval_loss = self.sess.run(tf.reduce_mean(eval_losses))

            print('Eval_loss: {}\n'.format(avg_eval_loss))



    def get_feed_dict(self, inps, trgts=None):
        """Creates the feed_dict that is fed into training or inference network.
           Pads inputs and targets.
           Returns feed_dict and sequence_length(s) depending on training mode.
        """
        if self.mode != 'INFER':
            inp_ids, sequence_lengths_1 = pad_sequences(inps,
                                                                               self.word2ind[self.pad],
                                                                               tail=False)

            feed = {
                self.ids_1: inp_ids,
                self.sequence_lengths_1: sequence_lengths_1
            }

            if trgts is not None:
                trgt_ids, sequence_lengths_2 = pad_sequences(trgts,
                                                                                    self.word2ind[self.pad],
                                                                                    tail=True)
                feed[self.ids_2] = trgt_ids
                feed[self.sequence_lengths_2] = sequence_lengths_2

                return feed, sequence_lengths_1, sequence_lengths_2

        else:

            inp_ids, sequence_lengths_1 = pad_sequences(inps,
                                                                               self.word2ind[self.pad],
                                                                               tail=False)

            feed = {
                self.ids_1: inp_ids,
                self.sequence_lengths_1: sequence_lengths_1
            }

            if trgts is not None:
                trgt_ids, sequence_lengths_2 = pad_sequences(trgts,
                                                                                    self.word2ind[self.pad],
                                                                                    tail=True)

                feed[self.sequence_lengths_2] = sequence_lengths_2

                return feed, sequence_lengths_1, sequence_lengths_2
            else:
                return feed, sequence_lengths_1

    def initialize_session(self):
        self.sess = tf.Session()
        self.sess.run(tf.global_variables_initializer())

    def restore_session(self, restore_path):
        self.saver.restore(self.sess, restore_path)
        print('Done.')

    def add_summary(self):
        """Summaries for Tensorboard."""
        self.training_summary = tf.summary.scalar('training_loss', self.train_loss)
        self.eval_summary = tf.summary.scalar('evaluation_loss', self.eval_loss)
        self.training_writer = tf.summary.FileWriter(self.summary_dir,
                                                     tf.get_default_graph())
        self.eval_writer = tf.summary.FileWriter(self.summary_dir)

# %% [markdown]
# ## The data
#
#
# The data we will be using with is a dataset from Kaggle, the Amazon Fine Food Reviews dataset.
# It contains, as the name suggests, 570.000 reviews of fine foods from Amazon and summaries of those reviews.
# Our aim is to input a review (Text column) and automatically create a summary (Summary colum) for it.
#
#
# https://www.kaggle.com/snap/amazon-fine-food-reviews/data

# %% [markdown]
# ### Reading and exploring

# %%
# load csv file using pandas.
file_path = "/content/drive/Datafile.csv"
data = pd.read_csv(file_path)
data.shape
data.head(10)
# Out:
#                                                  url  ...                                               Text
# 0  https://www.independent.co.uk/news/world/europ...  ...  Animals must be stunned prior to being killed ...
# 1  https://techxplore.com/news/2018-07-bacteria-p...  ...  Researchers in Canada have developed an innova...
# 2  http://www.themalaymailonline.com/malaysia/art...  ...  Southeast Asia is unprepared for the rapidly-r...
# 3  http://www.scotsman.com/business/companies/ret...  ...  In addition to calls from Toscafund to oust it...
# 4  http://www.wsj.com/articles/transferwise-plans...  ...  TransferWise has announced plans to launch a c...
# 5  http://www.standard.co.uk/news/uk/londoners-at...  ...  A lack of Vitamin D, polluted air, exposure to...
# 6  http://www.vanitatis.elconfidencial.com/estilo...  ...  Soft Silhouette can be used to treat sagging j...
# 7  http://www.japantimes.co.jp/news/2016/05/02/re...  ...  On 1 April 2016, a new Japanese law came into ...
# 8  https://www.msn.com/en-ph/foodanddrink/foodnew...  ...  Spacious, which offers a subscription-based se...
# 9  http://www.communitycare.co.uk/2017/07/20/coun...  ...  Difficulty attracting experienced social worke...
#
# [10 rows x 3 columns]

# %%
# we will only use the last two columns Summary (target) and Text (input).
data.head()
# Out:
#                                                  url  ...                                               Text
# 0  https://www.independent.co.uk/news/world/europ...  ...  Animals must be stunned prior to being killed ...
# 1  https://techxplore.com/news/2018-07-bacteria-p...  ...  Researchers in Canada have developed an innova...
# 2  http://www.themalaymailonline.com/malaysia/art...  ...  Southeast Asia is unprepared for the rapidly-r...
# 3  http://www.scotsman.com/business/companies/ret...  ...  In addition to calls from Toscafund to oust it...
# 4  http://www.wsj.com/articles/transferwise-plans...  ...  TransferWise has announced plans to launch a c...
#
# [5 rows x 3 columns]

# %%
column_names = data.columns
print(column_names)
# Out:
# Index(['url', 'Summary', 'Text'], dtype='object')

# %%
# check for missings --> got some in summary drop those. 
# 26 are missing, so we will drop those!
data.isnull().sum()
# Out:
# url         0
# Summary     3
# Text       11
# dtype: int64

# %%
data.dropna(how='all')
# Out:
#                                                      url  ...                                               Text
# 0      https://www.independent.co.uk/news/world/europ...  ...  Animals must be stunned prior to being killed ...
# 1      https://techxplore.com/news/2018-07-bacteria-p...  ...  Researchers in Canada have developed an innova...
# 2      http://www.themalaymailonline.com/malaysia/art...  ...  Southeast Asia is unprepared for the rapidly-r...
# 3      http://www.scotsman.com/business/companies/ret...  ...  In addition to calls from Toscafund to oust it...
# 4      http://www.wsj.com/articles/transferwise-plans...  ...  TransferWise has announced plans to launch a c...
# ...                                                  ...  ...                                                ...
# 39995  https://www.irishtimes.com/business/hammond-ta...  ...  UK Chancellor Philip Hammond is expected to in...
# 39996  http://www.tmcnet.com/usubmit/2015/07/30/82257...  ...  Livongo Health empowers people who have chroni...
# 39997  https://chemicalwatch.com/65818/furniture-flam...  ...  The capacity for flame retardants (FRs) to pro...
# 39998  https://www.insurancebusinessmag.com/asia/news...  ...  AXA Insurance has launched a one-stop, self-se...
# 39999  http://www.euronews.com/2016/09/16/berlin-elec...  ...  German Chancellor Angela Merkel's party is bra...
#
# [40000 rows x 3 columns]

# %%
# drop row, if values in Summary is missing. 
data.dropna(subset=['Summary'],inplace = True)
data.dropna(subset=['Text'],inplace = True)

# %%
# only summary and text are useful for us.
data = data[['Summary', 'Text']]
data.head()
# Out:
#                                              Summary                                               Text
# 0  Non-stunned halal and kosher meat not saleable...  Animals must be stunned prior to being killed ...
# 1  Solar cells powered by hybrid E. coli convert ...  Researchers in Canada have developed an innova...
# 2  Southeast Asia unprepared for ISIS attacks say...  Southeast Asia is unprepared for the rapidly-r...
# 3      Speedy Hire rejects calls for merger with HSS  In addition to calls from Toscafund to oust it...
# 4          TransferWise to launch China services\r\n  TransferWise has announced plans to launch a c...

# %%
column_names = data.columns
print(column_names)
# Out:
# Index(['Summary', 'Text'], dtype='object')

# %%
#Drop any rows which have any nans
data.dropna()
# Out:
#                                                  Summary                                               Text
# 0      Non-stunned halal and kosher meat not saleable...  Animals must be stunned prior to being killed ...
# 1      Solar cells powered by hybrid E. coli convert ...  Researchers in Canada have developed an innova...
# 2      Southeast Asia unprepared for ISIS attacks say...  Southeast Asia is unprepared for the rapidly-r...
# 3          Speedy Hire rejects calls for merger with HSS  In addition to calls from Toscafund to oust it...
# 4              TransferWise to launch China services\r\n  TransferWise has announced plans to launch a c...
# ...                                                  ...                                                ...
# 39995  UK chancellor to target offshore gambling comp...  UK Chancellor Philip Hammond is expected to in...
# 39996  ALLOY Health platform chosen by Livongo Health...  Livongo Health empowers people who have chroni...
# 39997  Furniture flame retardant smoke toxicity to be...  The capacity for flame retardants (FRs) to pro...
# 39998  AXA launches solutions integration platform fo...  AXA Insurance has launched a one-stop, self-se...
# 39999  German Chancellors' position at risk as Berlin...  German Chancellor Angela Merkel's party is bra...
#
# [39986 rows x 2 columns]

# %%
# we will not use all of them, only short ones and ones of similar size. 
# choosing the ones that are of similar length makes it easier for the model to learn.
raw_texts = []
raw_summaries = []

for text, summary in zip(data.Text, data.Summary):
    if 10< len(text) < 1000:
        raw_texts.append(text)
        raw_summaries.append(summary)

# %%
len(raw_texts), len(raw_summaries) ,
# Out:
# (39551, 39551)

# %%
for t, s in zip(raw_texts[:40], raw_summaries[:40]):
    print('Text:\n', t)
    print('Summary:\n', s, '\n')
# Out:
# Text:
#  Animals must be stunned prior to being killed in order for halal and kosher meat to be marketed with the official European Union (EU) organic label, the European Court of Justice has ruled. The judges argued that organic labelling reflects the highest animal welfare standards, and that stunning is integral to these as it significantly reduces suffering. The UK’s Food Standards Agency estimates that 88% of animals killed under halal methods are stunned. However, a minority of halal – and all kosher – meat is produced without stunning. The case was brought by a French animal welfare association in 2012.
#
# Summary:
#  Non-stunned halal and kosher meat not saleable as organic: ECJ
#
# Text:
#  Researchers in Canada have developed an innovative solar cell which uses bacteria to convert light into energy. The team at the University of British Columbia developed a way of genetically engineering E.coli to produce large amounts of lycopene, a natural dye which bacteria use for photosynthesis. By coating the bacteria with a semiconducting substance and incorporating it into a battery cell, they were able to achieve a current density of 0.686 milliamps per square centimetre, which they say is the highest yet achieved by a biogenic solar cell.
# Summary:
#  Solar cells powered by hybrid E. coli convert light to energy
#
# Text:
#  Southeast Asia is unprepared for the rapidly-rising threat of extremist attacks, warns think tank The Institute for Policy Analysis of Conflict (IPAC). It suggests the main danger is in the southern Philippines, where a few Islamic extremist groups have sworn allegiance to ISIS; the groups have links to other parts of the region, particularly Malaysia and Indonesia. ISIS has also endorsed a Philippines-based militant leader for Southeast Asia and widened its "extremist recruitment pool" in the region, opening up channels for international funding and communication. IPAC says as ISIS loses territory in Syria and Iraq, it raises the risk of revenge attacks in Southeast Asia.
# Summary:
#  Southeast Asia unprepared for ISIS attacks says think-tank
#
# Text:
#  In addition to calls from Toscafund to oust its Executive Chairman, Jan Astrand, Speedy Hire has also rejected calls for a merger with HSS Hire.
#
# Summary:
#  Speedy Hire rejects calls for merger with HSS
#
# Text:
#  TransferWise has announced plans to launch a currency transfer service to China this year. However to begin with, the new service won’t allow transfers out of the country, it will only convert other currencies into yuan, buying the currency on the wholesale market. “Our customers will be able to transfer their money from China over TransferWise by the end of the year,” the company said in a statement.
#
# Summary:
#  TransferWise to launch China services
#
#
# Text:
#  A lack of Vitamin D, polluted air, exposure to some pesticides and excessive minerals in drinking water can all raise the risk of dementia, researchers have said. Analysing a number of studies, the University of Edinburgh research team said that environmental risk factors, such as those found in pollutant-heavy areas, can contribute to the onset of dementia. A third of dementia patients’ illness remains unexplained, leaving environmental factors as a likely cause.
#
# Summary:
#  Pollution and other environmental factor linked to dementia
#
# Text:
#  Soft Silhouette can be used to treat sagging jowls for more than a year. Surgical wires of polylactic acid are inserted into the area with a microneedle while the doctor adjusts the suture in the area to reshape the surface of the skin. This then causes the production of new collagen and elastin.
#
# Summary:
#  Soft Silhouette is used to treat sagging skin
#
# Text:
#  On 1 April 2016, a new Japanese law came into effect, banning “unjust discrimination” against people with disabilities, and requiring government agencies and private sector businesses to make “reasonable adjustments” to remove social barriers for the nation’s 7.8m people with impairments. The Law to Eliminate Discrimination against People with Disabilities is the first action by the Japanese Government to align its domestic laws with the United Nations Convention on the Rights of Persons with Disabilities. Clarity on the exact definition of what constitutes discrimination is being sought by rights advocates, with the government responding by setting up standards databases and regional councils for resolving disputes. A review of the law is planned for 2019, however in the meantime, the Japan Disability Forum is calling for independent oversight.
#
# Summary:
#  Japan's new law bans bias against disabilities
#
# Text:
#  Spacious, which offers a subscription-based service that gives its members access to more than 100 New York restaurants to use as daytime workspaces, has announced that Barcino is to be its latest restaurant partner in San Francisco where it launched in autumn 2017. The company, which offers membership from $99 per month is starting to see competition from other start-ups such as KettleSpace in this niche of the co-working sector.
#
# Summary:
#  San Francisco restaurants serve up more co-working spaces
#
# Text:
#  Difficulty attracting experienced social workers has led local UK authorities to look abroad to recruit, with 450 social workers coming to the UK last year from countries including Zimbabwe, Romania, Portugal, Australia and India. Harrow council recently hired 20 children’s social workers from India. Official statistics reportedly showed that for 2016; the council’s workforce had 115 children’s social workers, recruited around 40 that year, a third of its children’s social work posts were filled with agency staff. In addition to experience, linguistic skills and cultural fit with certain community profiles was also noted as a benefit of overseas hires.
#
# Summary:
#   UK councils tripled overseas hires of social workers between 2012 and 2016
#
# Text:
#  Good cost control as volumes returned and improvements in most major markets helped Volvo Construction Equipment to post a 36% YoY increase in net sales in Q2 2017.
#
# Summary:
#   Improvements in major markets help Volvo Construction Equipment sales in Q2
#
# Text:
#  The US military needs 17 GW of solar capacity by 2025 to guarantee functionality in the event of a catastrophic cyber attack on the US grid, according to Professor Joshua Pearce, academic engineer at Michigan Tech. As reliance on remotely piloted vehicles grows, distributed power generation and microgrids, comprising solar panels and energy storage facilities, are crucial to the country's military infrastructure, said Pearce. Lockheed Martin has developed a demonstration system at Fort Bliss in Texas, capable of producing reliable clean energy and reducing costs.
#
# Summary:
#  Solar power could greatly benefit the US military
#
# Text:
#  The closing of WeWork’s $850m purchase of Lord & Taylor’s flagship Manhattan store has been delayed from 1 August to 13 November. The co-workspace operator has reportedly amended details of the transaction and perhaps lowered the cash portion of the deal.
#
# Summary:
#  WeWork changes terms, delays Lord & Taylor deal
#
# Text:
#  UK house builder Redrow has generated a land value of more than £4m ($5.3m) and agreed to protect £3m of that sum as part its a strategic partnership with Liverpool Mutual Homes and Liverpool City Council. The joint venture aims to build 1,500 new homes by 2020, with the city council offering up local authority land for sale to Redrow. That money is then ring-fenced, while Liverpool Mutual Homes builds affordable housing. Two hundred and fifty units have been delivered since the scheme's launch in February 2015, with another 150 under construction.
#
# Summary:
#  Liverpool Mutual Homes partners with City Council and Redrow
#
# Text:
#  Luxury car maker Genesis Motor America launched a redesigned website that included two interactive tools that enable users to build a virtual vehicle complete with animations that mimic functions such as opening the sunroof. One of the tools allows Instagram users to build their car on the app using Instagram Stories. Innocean lead the project handling the creative and concept design. MediaMonks was one of four other companies that participated on the project, working on the WebGL Game Engine.
#
# Summary:
#  MediaMonks help re-build lux car site
#
# Text:
#  President and Founder of HomeGate Real Estate, Paul Tippetts, talks about the firm’s model for selling real estate, which includes using flexible workspace provided by Regus. With 92% of business started online, HomeGate believes money is better spent on advertising, because that is where buyers are searching, rather than on a 5,000-square foot building that usually sits empty, as these days agents only occasionally require an office space. Tippetts boasts that “When customers ask where our office is, we can happily say. "Where would you like to meet, we have over 3,000 locations to choose from" In the Charleston location we have 3 locations to choose from, and it's nice to be able to use it when you need it.”
#
# Summary:
#   Real estate firm founder promotes benefits of using Regus workspace
#
# Text:
#  Spaces is opening its first two co-working centres in Hungary. The venues, located in Budapest’s Corvin Quarter and Vaci Road, each occupy approximately 3,500 sqm of space. Corvin Spaces is designed along classic lines while White House Spaces has a more modern loft-style feel.
#
# Summary:
#  Spaces opens two locations in Budapest
#
# Text:
#  Cam Wolf writing for GQ Magazine said it was a "pleasant surprise" to see the rap artist Kanye West wearing a Cartier Crash watch while giving chat show host David Letterman a tour of his home. He said West had eschewed more predictable choices such as Patek Philippe, Rolex or Richard Mille's sports watches. Legend has it that the Cartier Crash, designed by the firm in 1967, takes its inspiration from a watch recovered from a wrecked car, the timepiece having survived but melted into a strange shape.
#
#
# Summary:
#  Kanye West praised for sporting vintage Cartier Crash watch
#
# Text:
#  Real Madrid president Florentino Perez could be set to approve spending the club’s €200m ($226m) transfer budget on signing Mauro Icardi from Serie A's Inter Milan. It is not known, however, whether the Italian club can be persuaded to sell its captain.
# Summary:
#  Florentino Perez may give Madrid the go ahead to sign Icardi
#
# Text:
#  Real-estate tech has become hot property for VC funds. Struggling to find seed funding when it launched in 2012, coworkspace operator Industrious was forced to tap friends and family for $8m. By early 2018, two rounds later, it had raised a total of $142m and had a list of 64 funds keen to invest in the sector. Industrious is one of hundreds benefiting from the explosion of interest in real-estate venture investment. From 2012 to 2017, investment in US real-estate tech leapt from $44.7m to $5.7bn, according to Pitchbook, as VC funds exclusively devoted to the sector emerged and family real-estate companies created their own VC vehicles.
#
# Summary:
#  VC funds clamour to invest in real-estate start-ups
#
# Text:
#  Warner Music Group (WMG) has purchased "select assets" from live music platform Songkick, including its concert discovery app, website and the Songkick trademark. The platform will be run as a standalone brand overseen by WMG's artist and label services division, WEA. Some of Songkick's employees involved in running the concert discovery app will join the WMG team. Songkick's ticketing business and associated pending litigation, including its lawsuit against Live Nation over the alleged theft of trade secrets, are not included in the deal, financial details for which were not disclosed.
#
# Summary:
#   Warner Music Group buys select assets of music platform Songkick
#
# Text:
#  While they believe vehicle automation will significantly reduce accidents, British insurers, including esure, have voiced concerns over ‘autonomous ambiguity’ as vehicles with different levels of autonomy take to the roads. The insurers have called for international regulators to make clear distinctions between assisted and automated systems, and set out criteria for marketing such vehicles. It is suggested that "intermediate automated systems", which offer significant self-driving capability but require drivers to reclaim control of the vehicle in certain circumstances, could leave drivers confused and lead to a short-term tick up in accidents.
#
# Summary:
#   British insurers call for clear distinctions on automated vehicle systems
#
# Text:
#  Researchers at the University of Antwerp are building a robot that translates speech into sign language. The project was conceived by three masters students who identified a shortage of sign language translators, particularly for the Flemish sign language. By partnering with 3D printing company 3D Hubs to provide parts for the robot, the researchers will enable manufacturing to be scaled efficiently. 3D-printed parts will also be easy to replace.
#
# Summary:
#  Dutch researchers build sign language robot
#
# Text:
#  Petrofac has won a 36-month contract, worth around $115m, for the development of the Qarn Alam Co-Generation Project. The deal is the latest in a series of awards for the company in Oman and the second since it entered into a long-term framework agreement with Petrol Development Oman last year. The scope of the project, which will be managed from its Muscat office, includes installation and commissioning support for a gas turbine generator package with one heat recovery steam generator.
#
# Summary:
#  Petrofac wins contract in Oman
#
# Text:
#  S4 Capital is close to acquiring MightyHive, with a deal expected within the next few days, according to The Mail on Sunday. The deal would be S4 Capital’s second acquisition since it was founded earlier this year; it beat WPP in a bidding war for MediaMonks in June.  US programmatic ad firm MightyHive has been valued at up to $200m.
#
# Summary:
#  Bid for MightyHive expected this week
#
# Text:
#  Redrow sponsored the Local Champions Award category in a band contest that was won by Marsden Silver Band, which impressed at the Saddleworth and Oldham Whit Friday Brass Band Contests. The annual contest saw over 100 bands from all over the world compete in various categories. Marsden Silver Band said the £750 prize money would go towards covering expenses for the next competition.
#
# Summary:
#  Redrow sponsors £750 prize for Local Champion Award in annual band contest
#
# Text:
#  Savills has opened its online listings search platform for flexible workspace in the US. Workthere, which launched in London in 2017, allows users to search online before connecting with an adviser who negotiates on their behalf. The platform is up and running in New York and the company plans to open in theWest Coast later this year as it looks to expand across the US. Workthere has 3,000 listings in Europe and Singapore,ragingfrom big-name providers to smaller operators.
#
# Summary:
#  Savills launches flexible workspace platform in the US
#
# Text:
#  Sky and TalkTalk broadband users in South London were left without service at the weekend after rats chewed through fibre cables. “The most effective way of avoiding network downtime is to ensure there is a reliable failover“, said Hubert Da Costa, VP EMEA at Cradlepoint, who suggesting bridging the gap to an expensive wired connection upgrade with wireless WAN failover.
#
# Summary:
#   Wireless WAN failover suggested after rats take down TalkTalk in South London
#
# Text:
#  Ofcom’s latest league tables of complaints concerning suppliers of landlines and mobile phones, broadband and pay-TV services lists TalkTalk as the most complained about pay-TV provider in Q1 2019. The regulator received 14 complaints per 100,000 consumers about TalkTalk, doubling its Q4 2018 tally. Complaints handling was cited as an issue by 33% of customers, with 27% troubled by contract details, and 18% unhappy about billing, pricing and charges. BT and Virgin Media came second and third in the table, with 10 and seven complaints per 100,000 subscribers respectively.
#
# Summary:
#  TalkTalk most complained about pay-TV provider
#
# Text:
#  The New Development Bank has approved a loan for the Putian Pinghai Bay offshore wind farm project in Fujian Province, China. With the aim of meeting the infrastructure needs of its members, the bank will loan $290m to the government of China for the construction of a capacity of 250 MW in the offshore project.
#
# Summary:
#  New Development Bank confirms $290m Chinese offshore wind farm
#
# Text:
#  Two more lawsuits have been added to SunEdison’s growing number of legal challenges, including one from its own yieldco. TerraForm Global is claiming that SunEdison used money allocated for projects in India to improve its own balance sheet. In 2015, the yieldco paid $231m to its parent for a portfolio of Indian projects, with the expectation that SunEdison would use the funds to complete the work and subsequently transfer the plants to TerraForm Global. In the second filing, DE Shaw and Madison Dearborn, acting on concerns that SunEdison will go bankrupt, have launched a lawsuit against SunEdison and its other yieldco, TerraForm Power, insisting that the companies owe them $231m as part of SunEdison $2.4bn acquisition of First Wind Holdings from January 2015.
#
# Summary:
#  TerraForm Global joins list of those suing SunEdison
#
#
# Text:
#  WeWork has signed a lease for 2 Minster Court, part of the Minster Court estate in London’s financial district. The landmark office will  have space to accommodate 1,000 members.
#
# Summary:
#  WeWork to open in London’s Minster Court estate
#
# Text:
#  Drivers working for Uber Australia are not employees, according to a ruling from the Fair Work Ombudsman. The decision conflicts with the UK where Uber drivers were judged to be employees by the court of appeal. The Transport Workers Union called the Australian ruling devastating and said it risks eroding working standards in all industries. The Australia Institute's Centre for Future Work claimed UberX drivers earn AUD14.62 ($10.19) an hour compared with the country's minimum wage of AUD19.40 from 1 July.
# Summary:
#  Uber Australia does not employ drivers, Fair Work Ombudsman rules
#
# Text:
#  UK broadband bills are likely to rise, according to digital minister Matt Hancock, cited in the Telegraph, after the Government proposed that BT be allowed to include the costs of providing internet service to millions of rural Britons in its wholesale prices. Sky and TalkTalk are putting pressure on Ofcom to cut prices further based on claims of excessive profits made by Openreach. TalkTalk has called for the creation of a joint industry fund to pay for rural costs, which it says should be considered separately. BT and Virgin Media suggest strict proposals will curb investment in rolling out ultra-fast fibre optics. Mr Hancock said: “I’m keen to see the right incentives for investment in full fibre.”
#
# Summary:
#   Proposed rural broadband deal stokes row over Openreach
#
# Text:
#  John Tutte, CEO of Redrow, is calling for a standardised planning approach to parking. “In London, fewer people want or need a car parking space and having to incorporate them in some boroughs and not in others is inconsistent and has an impact on density.” Housing developers are increasingly meeting the needs of eco-friendly car owners, especially in the luxury market. Some, such as London’s Battersea Place, offer a car pool service as well as a chauffeur, while at Barratt Homes development Fulham Riverside in south-west London, a year's free membership of a car pool scheme is included. In Cambridge, housebuilder Hill is offering a £50 driving credit for a Zipcar scheme close to its Magna development, and even 18th-century Woolley House in Dorset comes with a solar-powered car charging point.
#
# Summary:
#  John Tutte, CEO of Redrow, calls for a standardised planning approach to parking
#
# Text:
#  Serviced office provider Regus is adding a business centre in Nairobi, increasing its co-working facilities to eight across Kenya. The company said that Kenya is the second preferred location for business tourism in Africa after South Africa, making it an ideal location for flexible workspaces. Regus first set up in Kenya in 2007. The co-working site will open in October.
#
# Summary:
#  Regus to open business centre in Nairobi
#
# Text:
#  WeWork is among four teams selected by the Presidio Trust to submit proposals for the development of San Francisco's 200-year-old former military base Fort Scott. WeWork proposes creating a mixed-use campus on the 30-acre bayside site overlooking the Golden Gate Bridge. To satisfy the board's demand that space be dedicated to socially conscious pursuits, WeWork will allocate room for non-profit organisations. Rival bids envisage creating an Epicenter for Climate Solutions and a research base for studying AI. The World Economic Forum has proposed a centre dedicated to studying the "fourth industrial revolution".
#
# Summary:
#  WeWork shortlisted to develop historic San Francisco fort
#
# Text:
#  Online office space marketplace Truss reports that demand for space in WeWork offices is three times greater than that of its nearest rival, and six times more than demand for desks in Regus offices, despite the IWG brand having a bigger footprint according to Truss founder Tom Smith. The WeWork name has become ubiquitous with co-working, giving the company a massive advantage, he said. However, he said it is hard to see how being better known, having better designed offices, free beer and more chic décor than the competition translates to a value ten times greater than IWG. WeWork claims its builders are a “global physical platform” providing valuable sources of data that is used to power a range of other services and value-added products, which are expected to provide higher margin incremental cash flow.
#
# Summary:
#  Demand for WeWork offices six times greater than Regus
#
# Text:
#  Petrofac has been awarded a contract by Ineos, building on their existing relationship. The three-year deal is to provide operations and maintenance crew for its Forties pipeline business based in the central North Sea. Petrofac staff will serve on the Unity platform and onshore at the Cruden Bay Terminal and other landline sites. Financial details were not disclosed; however, in February, Ineos said it would invest £500m ($607m) to extend the lifespan of the Forties Pipeline System by 20 years or more.
#
# Summary:
#  Ineos awards Petrofac three-year North Sea contract
#
# Text:
#  Spotify has added 10 million paying subscribers to its user base since September, the music-streaming company tweeted. As well as Spotify's 50 million paid-for subscribers, it has another 50 million non-paying users who are served third-party ads. By comparison, Apple Music had 20 million paying users as of last December, however, its service is less than two years old. Apple is planning to add original video content in a bid to enhance the experience of its service and attract more users.
#
# Summary:
#  Spotify has 50 million paying subscribers, while Apple Music has just 20 million

# %% [markdown]
# ### Clean and prepare the data

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# the function gives us the option to keep_most of the characters inisde the texts and summaries, meaning
# punctuation, question marks, slashes...
# or we can set it to False, meaning we only want to keep letters and numbers like here.
processed_texts, processed_summaries, words_counted = preprocess_texts_and_summaries(
    raw_texts,
    raw_summaries,
     keep_most=False
)
# Out:
# Processing Time:  33.627824783325195

# %%
for t,s in zip(processed_texts[:20], processed_summaries[:20]):
    print('Text\n:', t, '\n')
    print('Summary:\n', s, '\n\n\n')
# Out:
# Text
# : ['animals', 'must', 'be', 'stunned', 'prior', 'to', 'being', 'killed', 'in', 'order', 'for', 'halal', 'and', 'kosher', 'meat', 'to', 'be', 'marketed', 'with', 'the', 'official', 'european', 'union', 'eu', 'organic', 'label', 'the', 'european', 'court', 'of', 'justice', 'has', 'ruled', 'the', 'judges', 'argued', 'that', 'organic', 'labelling', 'reflects', 'the', 'highest', 'animal', 'welfare', 'standards', 'and', 'that', 'stunning', 'is', 'integral', 'to', 'these', 'as', 'it', 'significantly', 'reduces', 'suffering', 'the', 'uk', 's', 'food', 'standards', 'agency', 'estimates', 'that', '88', 'of', 'animals', 'killed', 'under', 'halal', 'methods', 'are', 'stunned', 'however', 'a', 'minority', 'of', 'halal', 'and', 'all', 'kosher', 'meat', 'is', 'produced', 'without', 'stunning', 'the', 'case', 'was', 'brought', 'by', 'a', 'french', 'animal', 'welfare', 'association', 'in', '2012']
#
# Summary:
#  ['non', 'stunned', 'halal', 'and', 'kosher', 'meat', 'not', 'saleable', 'as', 'organic', 'ecj']
#
#
#
# Text
# : ['researchers', 'in', 'canada', 'have', 'developed', 'an', 'innovative', 'solar', 'cell', 'which', 'uses', 'bacteria', 'to', 'convert', 'light', 'into', 'energy', 'the', 'team', 'at', 'the', 'university', 'of', 'british', 'columbia', 'developed', 'a', 'way', 'of', 'genetically', 'engineering', 'e', 'coli', 'to', 'produce', 'large', 'amounts', 'of', 'lycopene', 'a', 'natural', 'dye', 'which', 'bacteria', 'use', 'for', 'photosynthesis', 'by', 'coating', 'the', 'bacteria', 'with', 'a', 'semiconducting', 'substance', 'and', 'incorporating', 'it', 'into', 'a', 'battery', 'cell', 'they', 'were', 'able', 'to', 'achieve', 'a', 'current', 'density', 'of', '0', '686', 'milliamps', 'per', 'square', 'centimetre', 'which', 'they', 'say', 'is', 'the', 'highest', 'yet', 'achieved', 'by', 'a', 'biogenic', 'solar', 'cell']
#
# Summary:
#  ['solar', 'cells', 'powered', 'by', 'hybrid', 'e', 'coli', 'convert', 'light', 'to', 'energy']
#
#
#
# Text
# : ['southeast', 'asia', 'is', 'unprepared', 'for', 'the', 'rapidly', 'rising', 'threat', 'of', 'extremist', 'attacks', 'warns', 'think', 'tank', 'the', 'institute', 'for', 'policy', 'analysis', 'of', 'conflict', 'ipac', 'it', 'suggests', 'the', 'main', 'danger', 'is', 'in', 'the', 'southern', 'philippines', 'where', 'a', 'few', 'islamic', 'extremist', 'groups', 'have', 'sworn', 'allegiance', 'to', 'isis', 'the', 'groups', 'have', 'links', 'to', 'other', 'parts', 'of', 'the', 'region', 'particularly', 'malaysia', 'and', 'indonesia', 'isis', 'has', 'also', 'endorsed', 'a', 'philippines', 'based', 'militant', 'leader', 'for', 'southeast', 'asia', 'and', 'widened', 'its', 'extremist', 'recruitment', 'pool', 'in', 'the', 'region', 'opening', 'up', 'channels', 'for', 'international', 'funding', 'and', 'communication', 'ipac', 'says', 'as', 'isis', 'loses', 'territory', 'in', 'syria', 'and', 'iraq', 'it', 'raises', 'the', 'risk', 'of', 'revenge', 'attacks', 'in', 'southeast', 'asia']
#
# Summary:
#  ['southeast', 'asia', 'unprepared', 'for', 'isis', 'attacks', 'says', 'think', 'tank']
#
#
#
# Text
# : ['in', 'addition', 'to', 'calls', 'from', 'toscafund', 'to', 'oust', 'its', 'executive', 'chairman', 'jan', 'astrand', 'speedy', 'hire', 'has', 'also', 'rejected', 'calls', 'for', 'a', 'merger', 'with', 'hss', 'hire']
#
# Summary:
#  ['speedy', 'hire', 'rejects', 'calls', 'for', 'merger', 'with', 'hss']
#
#
#
# Text
# : ['transferwise', 'has', 'announced', 'plans', 'to', 'launch', 'a', 'currency', 'transfer', 'service', 'to', 'china', 'this', 'year', 'however', 'to', 'begin', 'with', 'the', 'new', 'service', 'won', 't', 'allow', 'transfers', 'out', 'of', 'the', 'country', 'it', 'will', 'only', 'convert', 'other', 'currencies', 'into', 'yuan', 'buying', 'the', 'currency', 'on', 'the', 'wholesale', 'market', 'our', 'customers', 'will', 'be', 'able', 'to', 'transfer', 'their', 'money', 'from', 'china', 'over', 'transferwise', 'by', 'the', 'end', 'of', 'the', 'year', 'the', 'company', 'said', 'in', 'a', 'statement']
#
# Summary:
#  ['transferwise', 'to', 'launch', 'china', 'services']
#
#
#
# Text
# : ['a', 'lack', 'of', 'vitamin', 'd', 'polluted', 'air', 'exposure', 'to', 'some', 'pesticides', 'and', 'excessive', 'minerals', 'in', 'drinking', 'water', 'can', 'all', 'raise', 'the', 'risk', 'of', 'dementia', 'researchers', 'have', 'said', 'analysing', 'a', 'number', 'of', 'studies', 'the', 'university', 'of', 'edinburgh', 'research', 'team', 'said', 'that', 'environmental', 'risk', 'factors', 'such', 'as', 'those', 'found', 'in', 'pollutant', 'heavy', 'areas', 'can', 'contribute', 'to', 'the', 'onset', 'of', 'dementia', 'a', 'third', 'of', 'dementia', 'patients', 'illness', 'remains', 'unexplained', 'leaving', 'environmental', 'factors', 'as', 'a', 'likely', 'cause']
#
# Summary:
#  ['pollution', 'and', 'other', 'environmental', 'factor', 'linked', 'to', 'dementia']
#
#
#
# Text
# : ['soft', 'silhouette', 'can', 'be', 'used', 'to', 'treat', 'sagging', 'jowls', 'for', 'more', 'than', 'a', 'year', 'surgical', 'wires', 'of', 'polylactic', 'acid', 'are', 'inserted', 'into', 'the', 'area', 'with', 'a', 'microneedle', 'while', 'the', 'doctor', 'adjusts', 'the', 'suture', 'in', 'the', 'area', 'to', 'reshape', 'the', 'surface', 'of', 'the', 'skin', 'this', 'then', 'causes', 'the', 'production', 'of', 'new', 'collagen', 'and', 'elastin']
#
# Summary:
#  ['soft', 'silhouette', 'is', 'used', 'to', 'treat', 'sagging', 'skin']
#
#
#
# Text
# : ['on', '1', 'april', '2016', 'a', 'new', 'japanese', 'law', 'came', 'into', 'effect', 'banning', 'unjust', 'discrimination', 'against', 'people', 'with', 'disabilities', 'and', 'requiring', 'government', 'agencies', 'and', 'private', 'sector', 'businesses', 'to', 'make', 'reasonable', 'adjustments', 'to', 'remove', 'social', 'barriers', 'for', 'the', 'nation', 's', '7', '8m', 'people', 'with', 'impairments', 'the', 'law', 'to', 'eliminate', 'discrimination', 'against', 'people', 'with', 'disabilities', 'is', 'the', 'first', 'action', 'by', 'the', 'japanese', 'government', 'to', 'align', 'its', 'domestic', 'laws', 'with', 'the', 'united', 'nations', 'convention', 'on', 'the', 'rights', 'of', 'persons', 'with', 'disabilities', 'clarity', 'on', 'the', 'exact', 'definition', 'of', 'what', 'constitutes', 'discrimination', 'is', 'being', 'sought', 'by', 'rights', 'advocates', 'with', 'the', 'government', 'responding', 'by', 'setting', 'up', 'standards', 'databases', 'and', 'regional', 'councils', 'for', 'resolving', 'disputes', 'a', 'review', 'of', 'the', 'law', 'is', 'planned', 'for', '2019', 'however', 'in', 'the', 'meantime', 'the', 'japan', 'disability', 'forum', 'is', 'calling', 'for', 'independent', 'oversight']
#
# Summary:
#  ['japan', 's', 'new', 'law', 'bans', 'bias', 'against', 'disabilities']
#
#
#
# Text
# : ['spacious', 'which', 'offers', 'a', 'subscription', 'based', 'service', 'that', 'gives', 'its', 'members', 'access', 'to', 'more', 'than', '100', 'new', 'york', 'restaurants', 'to', 'use', 'as', 'daytime', 'workspaces', 'has', 'announced', 'that', 'barcino', 'is', 'to', 'be', 'its', 'latest', 'restaurant', 'partner', 'in', 'san', 'francisco', 'where', 'it', 'launched', 'in', 'autumn', '2017', 'the', 'company', 'which', 'offers', 'membership', 'from', '99', 'per', 'month', 'is', 'starting', 'to', 'see', 'competition', 'from', 'other', 'start', 'ups', 'such', 'as', 'kettlespace', 'in', 'this', 'niche', 'of', 'the', 'co', 'working', 'sector']
#
# Summary:
#  ['san', 'francisco', 'restaurants', 'serve', 'up', 'more', 'co', 'working', 'spaces']
#
#
#
# Text
# : ['difficulty', 'attracting', 'experienced', 'social', 'workers', 'has', 'led', 'local', 'uk', 'authorities', 'to', 'look', 'abroad', 'to', 'recruit', 'with', '450', 'social', 'workers', 'coming', 'to', 'the', 'uk', 'last', 'year', 'from', 'countries', 'including', 'zimbabwe', 'romania', 'portugal', 'australia', 'and', 'india', 'harrow', 'council', 'recently', 'hired', '20', 'children', 's', 'social', 'workers', 'from', 'india', 'official', 'statistics', 'reportedly', 'showed', 'that', 'for', '2016', 'the', 'council', 's', 'workforce', 'had', '115', 'children', 's', 'social', 'workers', 'recruited', 'around', '40', 'that', 'year', 'a', 'third', 'of', 'its', 'children', 's', 'social', 'work', 'posts', 'were', 'filled', 'with', 'agency', 'staff', 'in', 'addition', 'to', 'experience', 'linguistic', 'skills', 'and', 'cultural', 'fit', 'with', 'certain', 'community', 'profiles', 'was', 'also', 'noted', 'as', 'a', 'benefit', 'of', 'overseas', 'hires']
#
# Summary:
#  ['uk', 'councils', 'tripled', 'overseas', 'hires', 'of', 'social', 'workers', 'between', '2012', 'and', '2016']
#
#
#
# Text
# : ['good', 'cost', 'control', 'as', 'volumes', 'returned', 'and', 'improvements', 'in', 'most', 'major', 'markets', 'helped', 'volvo', 'construction', 'equipment', 'to', 'post', 'a', '36', 'yoy', 'increase', 'in', 'net', 'sales', 'in', 'q2', '2017']
#
# Summary:
#  ['improvements', 'in', 'major', 'markets', 'help', 'volvo', 'construction', 'equipment', 'sales', 'in', 'q2']
#
#
#
# Text
# : ['the', 'us', 'military', 'needs', '17', 'gw', 'of', 'solar', 'capacity', 'by', '2025', 'to', 'guarantee', 'functionality', 'in', 'the', 'event', 'of', 'a', 'catastrophic', 'cyber', 'attack', 'on', 'the', 'us', 'grid', 'according', 'to', 'professor', 'joshua', 'pearce', 'academic', 'engineer', 'at', 'michigan', 'tech', 'as', 'reliance', 'on', 'remotely', 'piloted', 'vehicles', 'grows', 'distributed', 'power', 'generation', 'and', 'microgrids', 'comprising', 'solar', 'panels', 'and', 'energy', 'storage', 'facilities', 'are', 'crucial', 'to', 'the', 'country', 's', 'military', 'infrastructure', 'said', 'pearce', 'lockheed', 'martin', 'has', 'developed', 'a', 'demonstration', 'system', 'at', 'fort', 'bliss', 'in', 'texas', 'capable', 'of', 'producing', 'reliable', 'clean', 'energy', 'and', 'reducing', 'costs']
#
# Summary:
#  ['solar', 'power', 'could', 'greatly', 'benefit', 'the', 'us', 'military']
#
#
#
# Text
# : ['the', 'closing', 'of', 'wework', 's', '850m', 'purchase', 'of', 'lord', 'taylor', 's', 'flagship', 'manhattan', 'store', 'has', 'been', 'delayed', 'from', '1', 'august', 'to', '13', 'november', 'the', 'co', 'workspace', 'operator', 'has', 'reportedly', 'amended', 'details', 'of', 'the', 'transaction', 'and', 'perhaps', 'lowered', 'the', 'cash', 'portion', 'of', 'the', 'deal']
#
# Summary:
#  ['wework', 'changes', 'terms', 'delays', 'lord', 'taylor', 'deal']
#
#
#
# Text
# : ['uk', 'house', 'builder', 'redrow', 'has', 'generated', 'a', 'land', 'value', 'of', 'more', 'than', '4m', '5', '3m', 'and', 'agreed', 'to', 'protect', '3m', 'of', 'that', 'sum', 'as', 'part', 'its', 'a', 'strategic', 'partnership', 'with', 'liverpool', 'mutual', 'homes', 'and', 'liverpool', 'city', 'council', 'the', 'joint', 'venture', 'aims', 'to', 'build', '1', '500', 'new', 'homes', 'by', '2020', 'with', 'the', 'city', 'council', 'offering', 'up', 'local', 'authority', 'land', 'for', 'sale', 'to', 'redrow', 'that', 'money', 'is', 'then', 'ring', 'fenced', 'while', 'liverpool', 'mutual', 'homes', 'builds', 'affordable', 'housing', 'two', 'hundred', 'and', 'fifty', 'units', 'have', 'been', 'delivered', 'since', 'the', 'scheme', 's', 'launch', 'in', 'february', '2015', 'with', 'another', '150', 'under', 'construction']
#
# Summary:
#  ['liverpool', 'mutual', 'homes', 'partners', 'with', 'city', 'council', 'and', 'redrow']
#
#
#
# Text
# : ['luxury', 'car', 'maker', 'genesis', 'motor', 'america', 'launched', 'a', 'redesigned', 'website', 'that', 'included', 'two', 'interactive', 'tools', 'that', 'enable', 'users', 'to', 'build', 'a', 'virtual', 'vehicle', 'complete', 'with', 'animations', 'that', 'mimic', 'functions', 'such', 'as', 'opening', 'the', 'sunroof', 'one', 'of', 'the', 'tools', 'allows', 'instagram', 'users', 'to', 'build', 'their', 'car', 'on', 'the', 'app', 'using', 'instagram', 'stories', 'innocean', 'lead', 'the', 'project', 'handling', 'the', 'creative', 'and', 'concept', 'design', 'mediamonks', 'was', 'one', 'of', 'four', 'other', 'companies', 'that', 'participated', 'on', 'the', 'project', 'working', 'on', 'the', 'webgl', 'game', 'engine']
#
# Summary:
#  ['mediamonks', 'help', 're', 'build', 'lux', 'car', 'site']
#
#
#
# Text
# : ['president', 'and', 'founder', 'of', 'homegate', 'real', 'estate', 'paul', 'tippetts', 'talks', 'about', 'the', 'firm', 's', 'model', 'for', 'selling', 'real', 'estate', 'which', 'includes', 'using', 'flexible', 'workspace', 'provided', 'by', 'regus', 'with', '92', 'of', 'business', 'started', 'online', 'homegate', 'believes', 'money', 'is', 'better', 'spent', 'on', 'advertising', 'because', 'that', 'is', 'where', 'buyers', 'are', 'searching', 'rather', 'than', 'on', 'a', '5', '000', 'square', 'foot', 'building', 'that', 'usually', 'sits', 'empty', 'as', 'these', 'days', 'agents', 'only', 'occasionally', 'require', 'an', 'office', 'space', 'tippetts', 'boasts', 'that', 'when', 'customers', 'ask', 'where', 'our', 'office', 'is', 'we', 'can', 'happily', 'say', 'where', 'would', 'you', 'like', 'to', 'meet', 'we', 'have', 'over', '3', '000', 'locations', 'to', 'choose', 'from', 'in', 'the', 'charleston', 'location', 'we', 'have', '3', 'locations', 'to', 'choose', 'from', 'and', 'it', 's', 'nice', 'to', 'be', 'able', 'to', 'use', 'it', 'when', 'you', 'need', 'it']
#
# Summary:
#  ['real', 'estate', 'firm', 'founder', 'promotes', 'benefits', 'of', 'using', 'regus', 'workspace']
#
#
#
# Text
# : ['spaces', 'is', 'opening', 'its', 'first', 'two', 'co', 'working', 'centres', 'in', 'hungary', 'the', 'venues', 'located', 'in', 'budapest', 's', 'corvin', 'quarter', 'and', 'vaci', 'road', 'each', 'occupy', 'approximately', '3', '500', 'sqm', 'of', 'space', 'corvin', 'spaces', 'is', 'designed', 'along', 'classic', 'lines', 'while', 'white', 'house', 'spaces', 'has', 'a', 'more', 'modern', 'loft', 'style', 'feel']
#
# Summary:
#  ['spaces', 'opens', 'two', 'locations', 'in', 'budapest']
#
#
#
# Text
# : ['cam', 'wolf', 'writing', 'for', 'gq', 'magazine', 'said', 'it', 'was', 'a', 'pleasant', 'surprise', 'to', 'see', 'the', 'rap', 'artist', 'kanye', 'west', 'wearing', 'a', 'cartier', 'crash', 'watch', 'while', 'giving', 'chat', 'show', 'host', 'david', 'letterman', 'a', 'tour', 'of', 'his', 'home', 'he', 'said', 'west', 'had', 'eschewed', 'more', 'predictable', 'choices', 'such', 'as', 'patek', 'philippe', 'rolex', 'or', 'richard', 'mille', 's', 'sports', 'watches', 'legend', 'has', 'it', 'that', 'the', 'cartier', 'crash', 'designed', 'by', 'the', 'firm', 'in', '1967', 'takes', 'its', 'inspiration', 'from', 'a', 'watch', 'recovered', 'from', 'a', 'wrecked', 'car', 'the', 'timepiece', 'having', 'survived', 'but', 'melted', 'into', 'a', 'strange', 'shape']
#
# Summary:
#  ['kanye', 'west', 'praised', 'for', 'sporting', 'vintage', 'cartier', 'crash', 'watch']
#
#
#
# Text
# : ['real', 'madrid', 'president', 'florentino', 'perez', 'could', 'be', 'set', 'to', 'approve', 'spending', 'the', 'club', 's', '200m', '226m', 'transfer', 'budget', 'on', 'signing', 'mauro', 'icardi', 'from', 'serie', 'a', 's', 'inter', 'milan', 'it', 'is', 'not', 'known', 'however', 'whether', 'the', 'italian', 'club', 'can', 'be', 'persuaded', 'to', 'sell', 'its', 'captain']
#
# Summary:
#  ['florentino', 'perez', 'may', 'give', 'madrid', 'the', 'go', 'ahead', 'to', 'sign', 'icardi']
#
#
#
# Text
# : ['real', 'estate', 'tech', 'has', 'become', 'hot', 'property', 'for', 'vc', 'funds', 'struggling', 'to', 'find', 'seed', 'funding', 'when', 'it', 'launched', 'in', '2012', 'coworkspace', 'operator', 'industrious', 'was', 'forced', 'to', 'tap', 'friends', 'and', 'family', 'for', '8m', 'by', 'early', '2018', 'two', 'rounds', 'later', 'it', 'had', 'raised', 'a', 'total', 'of', '142m', 'and', 'had', 'a', 'list', 'of', '64', 'funds', 'keen', 'to', 'invest', 'in', 'the', 'sector', 'industrious', 'is', 'one', 'of', 'hundreds', 'benefiting', 'from', 'the', 'explosion', 'of', 'interest', 'in', 'real', 'estate', 'venture', 'investment', 'from', '2012', 'to', '2017', 'investment', 'in', 'us', 'real', 'estate', 'tech', 'leapt', 'from', '44', '7m', 'to', '5', '7bn', 'according', 'to', 'pitchbook', 'as', 'vc', 'funds', 'exclusively', 'devoted', 'to', 'the', 'sector', 'emerged', 'and', 'family', 'real', 'estate', 'companies', 'created', 'their', 'own', 'vc', 'vehicles']
#
# Summary:
#  ['vc', 'funds', 'clamour', 'to', 'invest', 'in', 'real', 'estate', 'start', 'ups']

# %% [markdown]
# ### Create lookup dicts
#
# We cannot feed our network actual words, but numbers. So we first have to create our lookup dicts, where each words gets and int value (high or low, depending on its frequency in our corpus). Those help us to later convert the texts into numbers.
#
# We also add special tokens. EndOfSentence and StartOfSentence are crucial for the Seq2Seq model we later use.
# Pad token, because all summaries and texts in a batch need to have the same length, pad token helps us do that.
#
# So we need 2 lookup dicts:
#  - From word to index
#  - from index to word.

# %%
specials = ["<EOS>", "<SOS>","<PAD>","<UNK>"]
word2ind, ind2word,  missing_words = create_word_inds_dicts(words_counted,
                                                                       specials = specials)
print(len(word2ind), len(ind2word), len(missing_words))
# Out:
# 70853 70853 0

# %% [markdown]
# ### Pretrained embeddings
#
# Optionally we can use pretrained word embeddings. Those have proved to increase training speed and accuracy.
# Here I used two different options. Either we use glove embeddings or embeddings from tf_hub.
# The ones from tf_hub worked better, so we use those.

# %%
# the embeddings from tf_hub. 
# embed = hub.Module("https://tfhub.dev/google/nnlm-en-dim128/1")



embed = hub.Module("https://tfhub.dev/google/Wiki-words-250/1")


    
emb = embed([key for key in word2ind.keys()])

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    sess.run(tf.tables_initializer())
    embedding = sess.run(emb)
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore

# %%
embedding.shape
# Out:
# (70853, 250)

# %%
np.save('drive/Modle 3/tf_hub_embedding.npy', embedding)

# %% [markdown]
# ### Convert text and summaries
#
# As I said before we cannot feed the words directly to our network, we have to convert them to numbers first of all. This is what we do here. And we also append the SOS and EOS tokens.

# %%
# converts words in texts and summaries to indices
# it looks like we have to set eos here to False
converted_texts, unknown_words_in_texts = convert_to_inds(processed_texts,
                                                                                word2ind,
                                                                                eos = False)

# %%
converted_summaries, unknown_words_in_summaries = convert_to_inds(processed_summaries,
                                                                                        word2ind,
                                                                                        eos = True,
                                                                                        sos = True)

# %%
converted_texts[4]
# Out:
# [6589,
#  13,
#  160,
#  79,
#  5,
#  152,
#  9,
#  823,
#  1395,
#  75,
#  5,
#  41,
#  40,
#  33,
#  119,
#  5,
#  783,
#  14,
#  4,
#  31,
#  75,
#  1332,
#  284,
#  361,
#  2715,
#  84,
#  6,
#  4,
#  95,
#  23,
#  20,
#  165,
#  2889,
#  78,
#  2010,
#  62,
#  3219,
#  858,
#  4,
#  823,
#  17,
#  4,
#  3698,
#  53,
#  794,
#  112,
#  20,
#  22,
#  355,
#  5,
#  1395,
#  38,
#  317,
#  21,
#  41,
#  45,
#  6589,
#  16,
#  4,
#  181,
#  6,
#  4,
#  33,
#  4,
#  30,
#  28,
#  8,
#  9,
#  1154]

# %%
# seems to have worked well. 
print( convert_inds_to_text(converted_texts[1], ind2word),
       convert_inds_to_text(converted_summaries[1], ind2word))
# Out:
# ['researchers', 'in', 'canada', 'have', 'developed', 'an', 'innovative', 'solar', 'cell', 'which', 'uses', 'bacteria', 'to', 'convert', 'light', 'into', 'energy', 'the', 'team', 'at', 'the', 'university', 'of', 'british', 'columbia', 'developed', 'a', 'way', 'of', 'genetically', 'engineering', 'e', 'coli', 'to', 'produce', 'large', 'amounts', 'of', 'lycopene', 'a', 'natural', 'dye', 'which', 'bacteria', 'use', 'for', 'photosynthesis', 'by', 'coating', 'the', 'bacteria', 'with', 'a', 'semiconducting', 'substance', 'and', 'incorporating', 'it', 'into', 'a', 'battery', 'cell', 'they', 'were', 'able', 'to', 'achieve', 'a', 'current', 'density', 'of', '0', '686', 'milliamps', 'per', 'square', 'centimetre', 'which', 'they', 'say', 'is', 'the', 'highest', 'yet', 'achieved', 'by', 'a', 'biogenic', 'solar', 'cell'] ['<SOS>', 'solar', 'cells', 'powered', 'by', 'hybrid', 'e', 'coli', 'convert', 'light', 'to', 'energy', '<EOS>']

# %% [markdown]
# ## The model
#
# Now we can build and train our model. First we define the hyperparameters we want to use. Then we create our Summarizer and call the function .build_graph(), which as the name suggests, builds the computation graph.
# Then we can train the model using .train()
#
# After training we can try our model using .infer()

# %% [markdown]
# ### Training
#
# We can optionally use a cyclic learning rate, which we do here.
# I trained the model for 20 epochs and the loss was low then, but we could train it longer and would probably get better results.
#
# Unfortunately I do not have the resources to find the perfect (or right) hyperparameters, but these do pretty well.

# %%
# model hyperparametes
num_layers_encoder = 4
num_layers_decoder = 4
rnn_size_encoder = 512
rnn_size_decoder = 512

batch_size = 64
epochs = 100
clip = 5
keep_probability = 0.5
learning_rate = 0.0005
max_lr=0.005
learning_rate_decay_steps = 700
learning_rate_decay = 0.90


pretrained_embeddings_path = '/content/drive/Modle 3/tf_hub_embedding.npy'
summary_dir = os.path.join('./tensorboard', str('Nn_' + str(rnn_size_encoder) + '_Lr_' + str(learning_rate)))


use_cyclic_lr = True
inference_targets=True

# %%
len(converted_summaries)
# Out:
# 39551

# %%
round(39551*0.9)
# Out:
# 35596

# %%
# build graph and train the model 
reset_graph()
summarizer = Summarizer(word2ind,
                                   ind2word,
                                   save_path='/content/drive/Colab Notebooks/Model 3',
                                   mode='TRAIN',
                                   num_layers_encoder = num_layers_encoder,
                                   num_layers_decoder = num_layers_decoder,
                                   rnn_size_encoder = rnn_size_encoder,
                                   rnn_size_decoder = rnn_size_decoder,
                                   batch_size = batch_size,
                                   clip = clip,
                                   keep_probability = keep_probability,
                                   learning_rate = learning_rate,
                                   max_lr=max_lr,
                                   learning_rate_decay_steps = learning_rate_decay_steps,
                                   learning_rate_decay = learning_rate_decay,
                                   epochs = epochs,
                                   pretrained_embeddings_path = pretrained_embeddings_path,
                                   use_cyclic_lr = use_cyclic_lr,
                                   summary_dir = summary_dir)           

summarizer.build_graph()
summarizer.train(converted_texts[:35596], 
                 converted_summaries[:35596],
                 validation_inputs=converted_texts[35596:],
                 validation_targets=converted_summaries[35596:])


# hidden training output.
# both train and validation loss decrease nicely.
# Out:
# Loaded pretrained embeddings.
# WARNING:tensorflow:From <ipython-input-15-762b6ec99214>:156: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-15-762b6ec99214>:156: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-15-762b6ec99214>:253: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From <ipython-input-15-762b6ec99214>:253: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From <ipython-input-15-762b6ec99214>:382: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-15-762b6ec99214>:382: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/seq2seq/python/ops/helper.py:107: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.random.categorical` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/seq2seq/python/ops/helper.py:107: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.random.categorical` instead.
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Streaming output truncated to the last 5000 lines.
# Iteration: 86 of 556	train_loss: 4.0648
# Iteration: 88 of 556	train_loss: 3.5582
# Iteration: 90 of 556	train_loss: 2.8923
# Iteration: 92 of 556	train_loss: 3.1720
# Iteration: 94 of 556	train_loss: 2.5571
# Iteration: 96 of 556	train_loss: 3.4307
# Iteration: 98 of 556	train_loss: 3.5495
# Iteration: 100 of 556	train_loss: 2.9025
# Iteration: 102 of 556	train_loss: 3.0021
# Iteration: 104 of 556	train_loss: 2.9974
# Iteration: 106 of 556	train_loss: 2.3886
# Iteration: 108 of 556	train_loss: 3.0279
# Iteration: 110 of 556	train_loss: 3.2463
# Iteration: 112 of 556	train_loss: 2.9933
# Iteration: 114 of 556	train_loss: 3.6101
# Iteration: 116 of 556	train_loss: 3.0241
# Iteration: 118 of 556	train_loss: 2.9246
# Iteration: 120 of 556	train_loss: 2.9606

# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-db0cd8817411> in <module>()
#       1 # build graph and train the model
# ----> 2 reset_graph()
#       3 summarizer = Summarizer(word2ind,
#       4                                    ind2word,
#       5                                    save_path='/content/drive/Colab Notebooks/Model 3',
#
# NameError: name 'reset_graph' is not defined

# %% [markdown]
# ### Inference
# Now we can use our trained model to create summaries.

# %%
reset_graph()
summarizer = Summarizer(word2ind,
                                   ind2word,
                                   '/content/drive/Colab Notebooks/Model 3',
                                   'INFER',
                                   num_layers_encoder = num_layers_encoder,
                                   num_layers_decoder = num_layers_decoder,
                                   batch_size = len(converted_texts[:1400]),
                                   clip = clip,
                                   keep_probability = 1.0,
                                   learning_rate = 0.0,
                                   beam_width = 5,
                                   rnn_size_encoder = rnn_size_encoder,
                                   rnn_size_decoder = rnn_size_decoder,
                                   inference_targets = True,
                                   pretrained_embeddings_path = pretrained_embeddings_path)

summarizer.build_graph()
preds = summarizer.infer(converted_texts[:1400],
                         restore_path = '/content/drive/Colab Notebooks/Model 3',
                         targets = converted_summaries[:1400])
# Out:
# Loaded pretrained embeddings.
# Graph built.
# INFO:tensorflow:Restoring parameters from /content/drive/Colab Notebooks/Model 3
# INFO:tensorflow:Restoring parameters from /content/drive/Colab Notebooks/Model 3
# Done.
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#
# ResourceExhaustedError: 2 root error(s) found.
#   (0) Resource exhausted: OOM when allocating tensor with shape[7000,70853] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node dynamic_seq2seq/decoder/decoder/while/BeamSearchDecoderStep/output_projection/Tensordot/MatMul}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[dynamic_seq2seq/decoder/decoder/while/LoopCond/_209]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#   (1) Resource exhausted: OOM when allocating tensor with shape[7000,70853] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node dynamic_seq2seq/decoder/decoder/while/BeamSearchDecoderStep/output_projection/Tensordot/MatMul}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 0 successful operations.
# 0 derived errors ignored.
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-48-82254a5bd566> in <module>()
#      19 preds = summarizer.infer(converted_texts[:1400],
#      20                          restore_path = '/content/drive/Colab Notebooks/Model 3',
# ---> 21                          targets = converted_summaries[:1400])
#
# <ipython-input-7-762b6ec99214> in infer(self, inputs, restore_path, targets)
#     491             feed, _ = self.get_feed_dict(inputs)
#     492
# --> 493         infer_logits, s_ids = self.sess.run([self.infer_logits, self.sample_words], feed_dict=feed)
#     494         prediction_ids.append(s_ids)
#     495
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1382                     '\nsession_config.graph_options.rewrite_options.'
#    1383                     'disable_meta_optimizer = True')
# -> 1384       raise type(e)(node_def, op, message)
#    1385
#    1386   def _extend_graph(self):
#
# ResourceExhaustedError: 2 root error(s) found.
#   (0) Resource exhausted: OOM when allocating tensor with shape[7000,70853] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node dynamic_seq2seq/decoder/decoder/while/BeamSearchDecoderStep/output_projection/Tensordot/MatMul (defined at /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py:1748) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[dynamic_seq2seq/decoder/decoder/while/LoopCond/_209]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#   (1) Resource exhausted: OOM when allocating tensor with shape[7000,70853] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node dynamic_seq2seq/decoder/decoder/while/BeamSearchDecoderStep/output_projection/Tensordot/MatMul (defined at /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py:1748) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 0 successful operations.
# 0 derived errors ignored.
#
# Original stack trace for 'dynamic_seq2seq/decoder/decoder/while/BeamSearchDecoderStep/output_projection/Tensordot/MatMul':
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 456, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 486, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 438, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-48-82254a5bd566>", line 18, in <module>
#     summarizer.build_graph()
#   File "<ipython-input-7-762b6ec99214>", line 102, in build_graph
#     self.add_seq2seq()
#   File "<ipython-input-7-762b6ec99214>", line 196, in add_seq2seq
#     encoder_state)
#   File "<ipython-input-7-762b6ec99214>", line 347, in build_decoder
#     scope=decoder_scope)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/seq2seq/python/ops/decoder.py", line 469, in dynamic_decode
#     swap_memory=swap_memory)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/control_flow_ops.py", line 2753, in while_loop
#     return_same_structure)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/control_flow_ops.py", line 2245, in BuildLoop
#     pred, body, original_loop_vars, loop_vars, shape_invariants)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/control_flow_ops.py", line 2170, in _BuildLoop
#     body_result = body(*packed_vars_for_body)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/control_flow_ops.py", line 2705, in <lambda>
#     body = lambda i, lv: (i + 1, orig_body(*lv))
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/seq2seq/python/ops/decoder.py", line 412, in body
#     decoder_finished) = decoder.step(time, inputs, state)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/seq2seq/python/ops/beam_search_decoder.py", line 553, in step
#     cell_outputs = self._output_layer(cell_outputs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/base.py", line 548, in __call__
#     outputs = super(Layer, self).__call__(inputs, *args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/base_layer.py", line 854, in __call__
#     outputs = call_fn(cast_inputs, *args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/impl/api.py", line 234, in wrapper
#     return converted_call(f, options, args, kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/impl/api.py", line 439, in converted_call
#     return _call_unconverted(f, args, kwargs, options)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/impl/api.py", line 330, in _call_unconverted
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/layers/core.py", line 1039, in call
#     outputs = standard_ops.tensordot(inputs, self.kernel, [[rank - 1], [0]])
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_ops.py", line 4071, in tensordot
#     ab_matmul = matmul(a_reshape, b_reshape)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/util/dispatch.py", line 180, in wrapper
#     return target(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_ops.py", line 2754, in matmul
#     a, b, transpose_a=transpose_a, transpose_b=transpose_b, name=name)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/gen_math_ops.py", line 6136, in mat_mul
#     name=name)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/op_def_library.py", line 794, in _apply_op_helper
#     op_def=op_def)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 3357, in create_op
#     attrs, op_def, compute_device)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 3426, in _create_op_internal
#     op_def=op_def)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 1748, in __init__
#     self._traceback = tf_stack.extract_stack()

# %%
# show results
sample_results(preds,
                                      ind2word,
                                      word2ind,
                                      converted_summaries[:1200],
                                      converted_texts[:1200])
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# s4 capital is on the hunt for sources of first party data to give clients added value sir martin sorrell told shareholders during the company s first ever earnings call valuations are high sorrell said adding the holy trinity is first party data driving digital content and programmatic s4 capital is in takeover talks with two firms one that has access to 90 million retail customers records and another in the transportation sector with data relating to 100 million customers according to sorrell
#
# Actual Summary:
# s4 wants to acquire firms with first party data
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# otsuka foods plant based meat products are now available in japan frozen burgers made from soyabeans and plant based cheese made from soya milk cream are among the items available under the zero meat brand one of the few japanese firms to offer plant based meat products otsuka has entered the alternative meat market due to a rising number of people following vegetarian or vegan diets its products will be launched in the kanto region
#
# Actual Summary:
# otsuka launches range of plant based meat products
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# san francisco based realtex plans to eliminate the two hour commute by combining co working with co living the developer is proposing to build a 13 storey property in the city s soma neighbourhood with housing for 400 and office space for 200 in the first large scale development of its type each studio apartment would have its own bathroom and basic kitchen with residents sharing larger communal kitchens and lounges proposed plans also allow for space to be occupied by a theatre gym market or restaurant realtex is considering selling or leasing the entire development to one large employer
#
# Actual Summary:
# san francisco developer plans co work co live experiment
#
# Created Summary:
# san francisco developer plans aims open co live experiment
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# wework is partnering with capital enterprise to create a community for female founders in london the companies plan to support female founded and female led start ups providing companies with three months free hot desk membership mentoring educational resources and access to local investors wework offices will also be used to host capital enterprise events aimed at connecting female founders with the media investors and influential advisers the partnership will launch on 4 march just a few days before international women s day on 8 march
#
# Actual Summary:
# wework partners capital enterprise to support female led start ups
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# wework partnered with american actor producer and entrepreneur ashton kutcher to pitch a tv show based on its creator awards to nbc as its founders seek to promote the company as much more than a real estate business the project is currently on hold the co working firm also reportedly considered hiring oscar winning director martin scorsese to direct a series of videos promoting the brand ahead of its ipo initially invitations to analysts for its meeting on wall street last week were sent to tech and internet analysts before eventually allowing those who cover the real estate sector to attend
#
# Actual Summary:
# wework works hard at being seen as more than a real estate firm
#
# Created Summary:
# wework works hard a its sky its awareness than investments estate estate firm
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# a study of all co workspace office opening from june 2018 to april 2019 found london to be the world s fastest city for co working venues new york came second in terms of actual office openings while luxembourg boasts the highest density of co workspaces per capita followed by singapore and ireland results from the coworkingresources report also revealed that 65 3 of new facilities are opened by new business indicating that while existing providers dominate the market grow is coming largely from firms and business owners entering the sector for the first time
#
# Actual Summary:
# new entrants account for most new co workspace openings
#
# Created Summary:
# co entrants account in in new co seek openings
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# publishers are not prepared for growth in mobile technology with in house teams lacking necessary skills according to a report by digital advertising consultancy the 614 group among the 40 publishers surveyed were industry leaders cond nast and thomson reuters the report found that 50 of publishers trafficking workload is in mobile however only a quarter of teams have sufficient html5 skills while 50 used two or fewer mobile partners instead of their display advertising business the study also found that just 15 of publishers require viewability guarantees for half of their campaigns
#
# Actual Summary:
# publishers unprepared for mobile growth the 614 group
#
# Created Summary:
# publishers of mobile 27bn concerned search 614
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# spaces is preparing to open a 4 686 sqm co working centre next to madrid puerta de atocha station on 4 july the facility will be its fourth in madrid the company will open three other centres in the city before the end of this year
#
# Actual Summary:
# spaces to open fourth co working centre in madrid
#
# Created Summary:
# wework to to to to in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# verizon wireless is planning to launch 5g technology in the second half of 2018 in houston as part of the company s four market plan to deploy residential 5g broadband service transmitters and other required infrastructure are being moved into place with the sales of 5g service to begin in 2019 the network will outcompete most home broadbands and is expected to spur on new applications such as over the internet navigation for driverless cars
#
# Actual Summary:
# verizon to offer 5g service in houston
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# repsol sinopac has renewed petrofac s north sea contract to provide engineering support services as a tier 1 contractor for brownfield modifications and projects across its uk operated assets as well as its terminal at flotta
#
# Actual Summary:
# repsol sinopac awards petrofac north sea contract extension
#
# Created Summary:
# wework to to to in in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# san leon has confirmed that all resolutions with one exception were passed at the company s agm on 28 september the exception was the re election by rotation of raymond king the company secretary which was withdrawn at the start of the meeting due to king advising the board of his intention to resign as a director king will remain in the position until the end of 2018
#
# Actual Summary:
# san leon s company secretary to retire
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# south korean made dot is looking to target the 285m blind people in the world today providing a smart watch where physical dots are raised and lowered to form braille letters the device has the ability to display four braille characters at once and can translate text from web pages and emails as well as acting as a standard watch
#
# Actual Summary:
# first braille smart watch
#
# Created Summary:
# china s to to to for
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# speedy hire s traffic light fleet has been taken over by clancy plant in a new partnership agreement clancy plant has committed to providing full and continuous nation wide traffic management services for speedy hire and its growing client base including the design planning installation maintenance and removal of temporary traffic management kit some clancy plant employees will be integrated into speedy hire s partnered service team and in addition to its own depots its engineering teams and assets will be held in speedy s warrington multi service centre and dartford superstore
#
# Actual Summary:
# speedy hire hands traffic light fleet over to clancy plant
#
# Created Summary:
# speedy to to flight build to to to london full
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# the launch of wework space services signals a refocus towards underserved mid size companies wework has recently taken leases on smaller properties more suited to companies with between 10 and 250 employees that make up the largest chunk of the office market and tend to move more often than larger firms michael hershfield head of wework s medium business segment denied that the new strategy is in response to the rise of competitors such as knotel despite offering a one year rent holiday to tenants moving from competing co workspace firms in new york
#
# Actual Summary:
# wework seeks to win over mid sized firms
#
# Created Summary:
# wework plans to to to san sized in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# one in six gp surgeries in the uk have suspended non emergency appointments because of staff shortages according to a survey by pulse magazine during particularly busy periods patients are quizzed over the phone to determine whether they are ill enough to see a doctor of the gps surveyed 16 5 admitted to cancelling routine appointment in the last 12 months patients association s rachel power blamed long term failure in workforce management the uk government pledged to recruit 5 000 more gps by 2020 however the nhs has lost 1 300 doctors since 2015 with more leaving the profession than joining
#
# Actual Summary:
# gp shortage forces one in six surgeries to suspend non emergency appointments
#
# Created Summary:
# gp ni forces could shortage to surgeries 000 suspend police emergency appointments
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# michael pollack a former senior director of real estate for regus part of iwg has joined premier business centers in his new role as vice president director of real estate pollack will focus on expanding the flexible workspace operator s presence in the us and will oversee location acquisitions and renewals during his tenure at regus pollack more than doubled the number of company locations in the western half of the us
#
# Actual Summary:
# premier business centers bring in michael pollack from regus
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# as it faces growing competition from amazon asos has launched a chatbot on its facebook page intended to provide a more personalised experience the bot will assist shoppers in the uk and france with christmas gift ideas on their site the feature joins a slew of other recent innovations by the company including customer profiling and a pay later service available through its app the service encourages a try before you buy mentality allowing customers pay for items 30 days after the point of order amazon prime wardrobe offers a similar grace period
#
# Actual Summary:
# asos launches chatbot on its facebook page
#
# Created Summary:
# amazon retailers to immersive to service service
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# wework plans to open a co workspace facility within the warsaw hub project signing a pre lease agreement for 10 500 sqm in the three building mixed use development the 113 000 sqm complex is due to be completed in the coming months
#
# Actual Summary:
# wework signs pre lease agreement for warsaw hub
#
# Created Summary:
# wework to to to to in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# lone star has ceased talks with iwg announcing that it will not make a formal offer for the office group without disclosing the reason for terminating the negotiations
#
# Actual Summary:
# lone star says it will not make a bid for iwg
#
# Created Summary:
# regus opens to to in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# an association of australian actuaries has urged the insurance industry to focus more attention of mental health issues the australian actuaries institute said existing data around mental illness is insufficient and noted that many consumers have expressed disappointment at the way the industry deals with them the body is examining issues such as the exclusion of travel insurance coverage for those suffering with mental illness as well as issues around loss of income resulting from illness
#
# Actual Summary:
# australian actuaries urge increased focus on mental health
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# valued at 20bn and with expectations that softbank will soon invest a further 3bn to lift its value to 35bn sceptics question wework s viability in an industry prone to painful ups and downs even so the company has reimagined the corporate office slashing the per employee cost with efficient use of space and creating a happier working environment furthermore it has insulated the parent company from the inherent mismatch in leases by creating individual special purpose entities that own individual leases and is increasingly using revenue sharing leases and even after april s bond issue it still has relatively little debt
#
# Actual Summary:
# there s more to wework than meets the eye
#
# Created Summary:
# there shares to be wework lending meets it eye a ipo ipo
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# iwg is launching its franchise programme in the nordic region making it the nineteenth market where the model has been rolled out
#
# Actual Summary:
# franchise model to be launched in nordic region
#
# Created Summary:
# macquarie opens to to in in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# cityfibre has come under severe criticism for the way it s managing the implementation of a new broadband network in stirling scotland the company has been accused by residents of showing a lack of communication and lack of respect after its workers caused major traffic disruption when they closed roads over the christmas period many residents from the village of cambusbarron have claimed cityfibre failed to inform them about the extent of the planned closures as the company constructs a 10m 12 7m 1gbps fibre to the home broadband network
#
# Actual Summary:
# cityfibre berated over fibre rollout disruption
#
# Created Summary:
# cityfibre opens out about rollout
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# the durst organization one of the oldest family run real estate companies in new york is entering the flexible office space market is entering the flexible office space market from next week durst ready will offer turnkey spaces of between 2 500 sq ft and 25 000 sq ft on leases from six months to 15 years at a choice of five locations in manhattan durst which has also invested in and partnered on properties with co workspace operator convene joins boston properties hines silverstein properties and tishman speyer entering the flexible office market
#
# Actual Summary:
# durst latest landlord to set up flexible office brand
#
# Created Summary:
# durst group alter to numbers developers to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# china s zijin mining has agreed to become a strategic partner in state owned serbian copper mine rtb bor after pledging to pay 1 26bn for a 63 stake the acquisition is part of a wider bid by the serbian government to spur the country s economic growth by selling off state owned businesses to relieve pressure on the state budget as part of the agreement zijin mining will spend 320m on a new copper mine and 135m towards environmental improvement schemes but will also pay an additional 200m to settle the serbian mine s debt
#
# Actual Summary:
# chinese firm to partner with serbia s state owned copper mine
#
# Created Summary:
# chinese resources buys s joint s firm in copper copper
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# the car sharing market in south korea is reportedly seeing extremely fast expansion as young drivers take the chance to enjoy different vehicles rather than own one themselves the number of users in local car sharing clubs has risen from less than 200 000 users in 2013 to more than 3 million this year local analysts predict the market will grow by more than 100 this year as young tech savvy consumers spend less on buying cars which incur high maintenance costs but more on just renting or sharing them as a result market watchers are predicting hyundai the nation s largest automaker may enter the car sharing race as the firm is reportedly reviewing business opportunities via sharing its hybrid and electric vehicles keeping pace with general motors ford and volvo which have already started car sharing services internationally
#
# Actual Summary:
# hyundai eyes car sharing as the market takes off in south korea
#
# Created Summary:
# car sharing car in korea hit in new off
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# the iraqi oil ministry has reportedly walked away from negotiations over the ratawi gas hub after a former petrofac executive pleaded guilty to charges of bribery while the scandal was citied there is no sign that the ministry is taking action against the company s projects in the country or that it has been placed on a formal blacklist according to a report on an iraqi website
#
# Actual Summary:
# iraq ends ratawi gas hub contract negotiations
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# us flexible office space firm wework has applied for permission to take up residence in the 40 140 sq ft three storey 3101 park boulevard building in palo alto california which used to be occupied by groupon the co working company intends to carry out 1 8m of renovations to the building such as upgrading the exterior and installing a coffee bar with a view to offering around 725 shared desks at the property the previous tenant vacated the office before the end of 2018 paving the way for wework s first location in the palo alto area
#
# Actual Summary:
# wework files permit to renovate former groupon site in palo alto
#
# Created Summary:
# wework begins opens for office former meetup
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# talktalk ceo tristia harrison has reiterated the company s 15 year belief that broadband access is a right not a privilege and warned that the uk lags behind other nations in terms of fibre to the premises fttp penetration levels in a keynote address to connected britain harrison said other european countries had fttp levels of between 70 and 80 while the uk s current 5 was putting the digital economy at risk
#
# Actual Summary:
# broadband access a right not a privilege talktalk ceo
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# us carmaker ford and chinese tech firm baidu have unveiled a two year pilot scheme to develop and test level 4 autonomous vehicles cars which do not need a human driver no financial or other details were revealed but testing of ford s autonomous cars featuring baidu s apollo autonomous driving system is set to begin at the end of this year in june the two firms said they would seek out collaborations in artificial intelligence and connectivity
#
# Actual Summary:
# ford baidu to collaborate on testing avs in china
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# wework has signed a lease for 16 500 sqm in the former philips tower in brussels the multi tower is currently undergoing a major renovation to transform the property into a mixed use development
#
# Actual Summary:
# wework signs lease for 16 500 sqm space in philips tower
#
# Created Summary:
# wework to to to in in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# facebook has launched facebook pay a single payment system that integrates payments over all its networks the company said the e payment system should work with most major credit debit cards and paypal data captured from the payments system will be used to help its advertisers target ads
#
# Actual Summary:
# facebook pay to power targeted ads
#
# Created Summary:
# wework to to to to in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# blackrock s etf unit has filed with the sec to launch five currency hedged smart beta equity etfs which will take their total of us currency hedged etfs to 21 details of the new ishares are listed on the linked article
#
# Actual Summary:
# blackrock plans to issue currency hedge smart beta etfs
#
# Created Summary:
# wework to to to to in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# the uk government has set a 2020 deadline for communications regulator ofcom to fully implement its universal service obligation uso high speed broadband plan in two years time anyone in the uk has the legal right to an affordable 10 mbps broadband connection the uso which is expected to cost up to 1 1bn 1 5bn and will be funded by the industry and not the government as previously proposed was implemented under last year s digital economy act digital minister margot james said the plan put high speed broadband on a similar footing as other essential services like water and phone lines
#
# Actual Summary:
# government grants ofcom two years to action universal broadband
#
# Created Summary:
# uk grants ofcom launch years action action universal broadband
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# redrow homes has appointed seven people to its south west sales team to meet growing demand for its developments gail edmundson and lyn etherington will join the sales team at tascroft rise in warminster jeff davis and dawn perrill will work at badbury park near swindon while danielle edwards and rachel smith have been recruited to cherhill view caine and stanley park bristol respectively the appointments were made within the first three months of the year
#
# Actual Summary:
# redrow expands sales team in the south west to meet demand
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# wework has secured commitments from at least 10 banks for 6bn in credit facilities contingent on its ipo lead bank jpmorgan is understood to have been joined by bank of america barclays citigroup credit suisse deutsche bank goldman sachs hsbc morgan stanley ubs and wells fargo in agreeing to provide between 500m and 750m each for a 2bn letter of credit facility and a 4bn delayed draw term loan the 4bn tranche is expected to include a mechanism that will allow the debt to be switched into either a term loan b to be sold to institutional investors or a high yield bond after the company s ipo
#
# Actual Summary:
# 10 banks commit 6bn to wework credit facilities
#
# Created Summary:
# jpmorgan banks commit property retail wework prepares
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# solar developers hive energy and wirsol are closer to starting work on the uk s largest solar project so far a 350 mw plant on the kent coast final approval is expected in 2020 the developers have moved some panels after consultation with local residents and have proposed a range of biodiversity improvements and habitat protection schemes hive and wirsol will apply for a development consent order later this year
#
# Actual Summary:
# kent coast 350 mw solar farm uk s largest set for 2020 approval
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# southern california utility imperial irrigation district iid has successfully demonstrated the use of a battery energy storage system bess to perform a black start restoring power to an electric power generator without calling on external transmission lines in a move that could improve grid resilience earlier this month iid s 33 mw 20 mwh lithium ion bess kick started el centro generating station s 44 mw combined cycle natural gas turbine in what iid manager for energy department vicken kasarjian called a major accomplishment in the energy industry in january the same process was performed for the first time ever by german american technology firm younicos
#
# Actual Summary:
# california utility uses battery to black start conventional turbine
#
# Created Summary:
# doe utility uses to to black black conventional turbine
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# uk housebuilder redrow has agreed to work with housing association network homes to develop 10 apartments in bishop s stortford in hertfordshire the properties set to be finished in march consist of six homes earmarked for affordable rent and four for shared ownership the development is network homes first in bishop s stortford and is five minutes walk from the town centre
#
# Actual Summary:
# network homes exchanges contracts with redrow for herts flats
#
# Created Summary:
# china s to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# copenhagen based insurance firm tia technology is aiming to tap into the online market with the acquisition of peer to peer insurance platform gobundl tia s ceo christian kromann said customers of its gobundl s self service front end which uses machine learning and artificial intelligence could fill in a few small information points and be presented with insurance solutions no financial details of the deal were disclosed
#
# Actual Summary:
# denmark s tia technology buys insurtech gobundl
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# executives from several co working firms have expressed their belief that the industry is ripe for major consolidation over the next few years speaking at an industry event in washington d c anna squires levine of industrious said she expected in the future that a handful of major players would exist all with something slightly different to offer workready suites president austin flajser predicted co working would follow a similar path to the hospitality industry with larger brands bringing a number of others under one umbrella while convene s michael burke observed that scale was necessary to survive a downturn
#
# Actual Summary:
# insiders predict co working m a
#
# Created Summary:
# co working urged co london co working
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# us company vivint smart home saw a 735 lift in sales and 57 click through rate during a yahoo native gemini ad campaign in 2016 the campaign which ran from january to june was aimed at driving traffic to vivint s website and increase sales while internal tracking technology gave the company the opportunity to see who was buying their products and where in 2016 the interactive advertising bureau said mobile video and data would become game changers for native advertising in 2017
#
# Actual Summary:
# native ads help vivint smart home gain 735 sales lift
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# redrow owner steve morgan has received an honorary degree for his outstanding contribution to the building industry morgan received a doctor of business administration from the university of chester flintshire based redrow is one of the uk s most successful homebuilders and is listed on the ftse 250 morgan who started the company at the age of 21 said the award was a great personal honour adding i have always loved the city of chester it has been an integral part of the success of redrow where we have built many hundreds of houses over the years
#
# Actual Summary:
# steve morgan receives an honorary degree of doctor of business administration
#
# Created Summary:
# steve morgan morgan rejects honorary degree to doctor light to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# large companies account for about half of all co workspace members in india according to a knight frank study the report which surveyed senior management at 120 companies that occupy an estimated 21 65m sq m of office space worldwide said more than two thirds of companies globally intend increasing use of co workspace over the next three years increased flexibility was cited as the main driver by 55 of respondents 11 said the collaborative culture was a key benefit and another 11 liked the speed of getting a unit up and running
#
# Actual Summary:
# half of india s co workers employed by large companies
#
# Created Summary:
# co working increasingly landlords co co evolving
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# us music streaming service pandora has announced it is opening up its ad inventory for programmatic buying allowing marketers to reach a potential audience of millions the decision comes after the company tested a system for programmatic audio ads in february with 20 companies including volkswagen procter gamble and sony pictures participating the programmatic marketplace is being run by adswizz which pandora acquired in march for 145m the us market for audio ads grew by 39 to 1 6bn in 2017 according to industry analysts
#
# Actual Summary:
# pandora opens ad inventory
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# an iwg spv that operates the company s regus centre at 43 temple row in birmingham has appointed administrators to liquidate the company the 36 000 sq ft building is owned by legal general
#
# Actual Summary:
# regus temple row office in birmingham falls into administration
#
# Created Summary:
# wework to to to in in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# older adults who lived in neighborhoods where it was easy to walk to daily destinations were more physically active than those in less walkable neighborhoods a study in barcelona spain showed the results have implications for efforts to allow older adults to remain healthy and independent while they age in place in urban neighborhoods
#
# Actual Summary:
# walkable neighborhoods linked with more active older adults
#
# Created Summary:
# wework to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# maria dolores dancausa will step down from her position as a non executive board member of esure group after more than four years following the company s annual general meeting on 17 may 2018 esure cited business commitments as the reason for dancausa s decision
#
# Actual Summary:
# maria dolores dancausa to step down from esure board
#
# Created Summary:
# wework to to to to in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# redrow has been accused of using bullying tactics over the planned felling of a tree in corsham wiltshire the developer s burlington grange site is subject to conditions imposed by the planning inspectorate after being approved by the local council but redrow has received permission to cut down a tree on the junction of the a4 and bradford road residents and councillors opposed to the development said the felling is a bid to bully the council into granting final permission for the site even if conditions are not approved redrow confirmed it was working with planning but declined to comment on the tree
#
# Actual Summary:
# residents accuse developer of bullying tactics over tree felling
#
# Created Summary:
# residents accuse developer of bullying tactics under tree felling
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# new york city office landlords that have a track record of mitigating risk by filling their buildings with multiple tenants are breaking the rules for wework the flexible office operator has a total of five million sq ft in the city and occupies the entire rentable office space in at least five buildings in a dozen or more other buildings it occupies more than 50 of the space according to the real deal properties with high wework occupancies trade at higher capitalisation rates than the overall market rate for similar buildings according to a 2018 cushman wakefield study wework guarantees just 11 of its overall lease obligations the wall street journal reported in june some of the city s largest landlords have already begun to demand stronger guarantees from the company
#
# Actual Summary:
# some nyc landlords bend the rules for wework
#
# Created Summary:
# landlords nyc landlords bend as co manhattan wework
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# a us consumer interest group has cautioned that insurance companies have more information about customers than social networks the consumer federation of america said insurers often know more about individuals than legal authorities do and can collect sensitive data without the need for a warrant on such things as credit reports or the value of a customer s home companies are also increasingly gleaning information about customers via the use of artificial intelligence the national association of insurance commissioners has created a working group to assess how insurers are processing and using consumer sourced big data
#
# Actual Summary:
# insurers said to hold more consumer data than social networks
#
# Created Summary:
# insurers said to hold more consumer data
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# a not so small addition to yesterday s exposure of gameover zeus s business club set up it is being suggested that the group were not just involved in raiding banks but had also bought political protection in russia through undertaking some cyber espionage work for the state
#
# Actual Summary:
# gameover zeus gang boss also engaged in cyber espionage
#
# Created Summary:
# wework to to to to in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# co working giant wework could face challenges in the event of a downturn according to a survey of national real estate investor nrei readers the majority 39 4 of respondents thought demand for co working space in the us would continue to grow in the next year but 39 6 thought wework could face substantial challenges in a downturn respondents cited the ease of copying wework s business model and the difference between its own long term leases with landlords and its short term subleases with clients among potential risks however a wework spokesperson said they expect more businesses to turn to flexible space during a downturn
#
# Actual Summary:
# nrei readers split on wework surviving downturn
#
# Created Summary:
# nrei readers split on wework surviving downturn
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# s4 capital is raising 74m 94m through a placing and open offer on the london stock exchange to partially fund its acquisition of mightyhive
#
# Actual Summary:
# share sale to part fund mightyhive acquisition
#
# Created Summary:
# regus opens to to in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# allied irish banks aib has invested 30m 35m in cross border payments platform transfermate in a deal that gives the latter firm an estimated valuation of between 250m and 300m the two firms will also form a strategic partnership to offer irish businesses international payments and receivables capabilities ahead of brexit transfermate ceo terry clune said the funds would allow the company to expand its head office and technology functions in ireland as well as support its commercial teams around the world
#
# Actual Summary:
# aib invests 30m in cross border payments company transfermate
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# ride hailing company grab has plans to bring on 800 new staff over the next two years to bolster its six research and development centres in the us and asia grab a southeast asian rival to uber has doubled the number of centres it operates in the past three months its engineers and developers will be working on machine learning mobile first technology in app user experiences and predictive data analytics to expand grab s current offering the company is valued at over 3bn and operates in 39 cities in asia
#
# Actual Summary:
# grab to expand its research and development facilities
#
# Created Summary:
# lyft plans grab e services in in southeast
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# regus has signed a lease for an additional 2 300 sqm of office space in building c of krakow s equal business park which obtained its occupancy permit last month the flexible office space provider already occupies space in building b of the complex
#
# Actual Summary:
# regus leases another 2 300 sqm in krakow business park
#
# Created Summary:
# wework to to to to in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# britain s biggest retailer tesco has warned john west that it will stop stocking its canned tuna if the company does not change its cruel fishing practices john west which is owned by tuna giant thai union uses fish aggregating devices which are harmful to other kinds of marine life instead of the more sustainable pole and line method tesco s threat could be a damaging one to thai union as the uk is the second biggest tinned tuna consumer in the world the company assured greenpeace in 2011 that it would make the switch to sustainable fishing by the end of 2016
#
# Actual Summary:
# tesco to ban john west if it keeps using destructive fishing practices
#
# Created Summary:
# tesco proposes ban john west if cut keeps fishing destructive fishing practices
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# dermatologist andr braz has named sculptra as one of the five best procedures to ensure the youthful appearance of the skin in an article for brazilian lifestyle website caras
#
# Actual Summary:
# brazilian dermatologist recommends sculptra
#
# Created Summary:
# regus opens to to in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# mumbai based monk media network has acquired socialgiz ameya adhikari founder of the boutique social media company will join monk media as vp of finance and become a member of the board
#
# Actual Summary:
# socialgiz acquired by monk media network
#
# Created Summary:
# regus to to to in in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# knotel has signed leases on nine properties in manhattan amounting to around 200 000 sq ft this month the company s new york property base centred predominantly in lower manhattan and midtown south now exceeds two million sq ft
#
# Actual Summary:
# knotel signs leases for nearly 200 000 sq ft this month
#
# Created Summary:
# wework to to to to in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# advisers to the department of health have given bidders until friday to submit an offer for a majority stake in nhs professionals the staffing agency that supplies 90 000 doctors and nurses to hospitals across the uk companies expected to table bids include recruitment agency hays outsourcing giants healthcare locums and serco along with financial investors such as aurelius equity opportunities according to sources in whitehall bids are expected to value nhs professionals at about 50m and to be for a 70 stake with the government retaining a minority share the sale is being overseen by accountants deloitte
#
# Actual Summary:
# hcl expected to bid for majority stake in nhs staff agency
#
# Created Summary:
# hcl to sell replace discounts majority stake networks
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# spaces has opened its second centre houston located in the citycentre mixed use development the 60 000 sq ft facility features seven fully equipped meeting rooms as well as desk space and private offices spaces already has a site at richmond avenue in the city and plans to open a third next year in the galleria area
#
# Actual Summary:
# spaces to open second facility in houston
#
# Created Summary:
# wework to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# lord wolfson ceo of uk retailer next has backed prime minister boris johnson s tough brexit stance and said the eu is more likely to agree terms if the uk demonstrates it would accept a no deal outcome next regarded as a high street bellwether has a brexit steering committee to ensure it has the administrative legal and physical infrastructure in place should the uk s exit from the eu be disorderly
#
# Actual Summary:
# next chief executive stands behind uk pm on brexit stance
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# wework is enjoying strong demand in china according to wework s asia managing director christian lee and has just opened its seventh branch in the chinese mainland in wangjing according to the colliers international apac flexible workspace report 2017 appetite from operators for new centres is stronger than ever and we should see 30 growth in take up year on year lee noted that wework is enjoying 90 100 occupancy in china almost faster than anywhere else in the world
#
# Actual Summary:
# wework enjoys incredible demand in china
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# some big businesses are adopting the flexible office model integrating it into the way they operate siemens is one such company it first opened a co working office in munich in october 2017 and now has more than 120 newwow new way of working sites across more than 35 different countries the german conglomerate recently opened its first co working facility in the us located in boston it now has a total of nine co working spaces around the world in boston where it has 12 offices employing more than 2 000 people in the region siemens has split its co working space into three different areas designed to give employees a choice of places to work as it seeks to provide employees with flexibility in the way that they work and enable a culture of collaboration to be developed
#
# Actual Summary:
# corporates adopt co working model
#
# Created Summary:
# corporates adopt working working model
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# winter green research has published a new study titled robot cars and trucks market shares strategy and forecasts worldwide 2013 to 2019 the report focuses on the growth of automation in the automotive industry with uber and google set to be early adopters of the technology according to the report the benefits of automated driving include integrated radar based monitoring systems adaptive steering braking parking and lane assist technology which will all work off one central processor l eader of the study susan eustis explained that the market for robot car and truck vehicles is anticipated to expand in parallel with the deployment of appropriate roadway controls funded by government programs which will be rapidly adopted by commercial fleet vehicles after 2020 as automated systems are tested and approved
#
# Actual Summary:
# automated cars and trucks will be rapidly adopted after 2020
#
# Created Summary:
# swiss land s trucks vehicles for rapidly adopted years 2020
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# wework has signed a lease on six floors of dixon house 1 lloyds avenue the 34 000 sq ft site takes the number of wework locations in the city of london to 17
#
# Actual Summary:
# wework signs lease on 17th property in city of london
#
# Created Summary:
# wework to to to in in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# ...
#
# Actual Summary:
# uber gets political publicly endorsing nevada republican candidate
#
# Created Summary:
# uber gets political publicly endorsing nevada republican candidate
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# redrow was among the winners at the north west property awards held in liverpool earlier this month forth homes were headline sponsors for this year s event which took place at lutyens crypt in liverpool metropolitan cathedral and was presented by local actor neil fitzmaurice redrow picked up awards for show home of the year and property apprentice other winners included countryside abode and paul crowley co solicitors
#
# Actual Summary:
# redrow honoured at nwpas 2016
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# british insurance company aviva has launched a service inspired by how amazon analyses customer data in a similar way to amazon aviva uses data in its ask if never service to offer tailored recommendations without interrogating potential customers about security issues such as door locks or roof designs while the company said the use of data analytics should lessen the need for underwriting questions critics have said big data analysis creates the potential for price increases and conflicts of interest
#
# Actual Summary:
# aviva uses big data analysis to eliminate underwriting questions
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# mightyhive s japanese team has received certification as a google cloud platform partner for sales and service the media consultancy said the certification will help it to support its japanese clients to activate their data more effectively and guide them on strategic data management
#
# Actual Summary:
# mightyhive japan receives google cloud certification
#
# Created Summary:
# wework to to to to in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# the first wines from the french region of bordeaux have received favourable reviews from uk wine merchants the bordeux 2015 is a keenly anticipated vintage and considered to be a very good wine from this locale with critics rating it as very good or even great the vintage is being sold at prices higher than last year due to the fact it is proven in terms of quality that suggests it could be voted one of the best wines this century however wine merchants remain cautiously optimistic about this prediction claiming that it is too early to say until after the first growths have been considered they hope that these early signs of promise may cause a resurgence of interest in bordeaux amongst the public who have switched to sparkling wines
#
# Actual Summary:
# bordeaux 2015 very good to great
#
# Created Summary:
# bordeaux 2015 very good great great
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# ligue 1 club as monaco has signed a sponsorship deal with swiss watchmaker le rh ne the company will be the club s official watchmaker for the next two seasons the deal includes branding placement and signage within monaco s stadium and will see the launch of a limited edition watch
#
# Actual Summary:
# as monaco signs watch partnership with le rh ne
#
# Created Summary:
# wework to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# redrow is now completing the final phase of its award winning southbank development in newton kyme north yorkshire the development features georgian inspired townhouses and replaces the disused papyrus works with two new lots st andrew s place and the rectory the project was highly commended at the 2016 uk property awards
#
# Actual Summary:
# redrow is in its final phase of southbank development in newton kyme
#
# Created Summary:
# wework to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# iwg has launched its franchise operation in finland initially the company is looking for entrepreneurial partners to open regus offices across the country it also plans to include the spaces brand as part of its franchise offering iwg is seeking franchisees the good local knowledge and networks in the business community
#
# Actual Summary:
# iwg rolls out franchise operation in finland
#
# Created Summary:
# wework to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# tremor video is partnering with lg electronics to bring its native advertising to selected webos smart tvs tremor video provides entertainment advertisers with apps and ad placements that are native to the smart tv experience helping them to stand out with discoverable content designed to support the overall subscriber growth to streaming services
#
# Actual Summary:
# tremor video brings native ads to lg smart tvs
#
# Created Summary:
# wework to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# wework is set to open its first location in atlanta georgia beyond the city limits with the company examining potential locations in central perimeter and north fulton the company said the city would be on a par with miami in terms of the number of wework sites by early 2019 wework recently said it would add more space to its high performance computing centre in atlanta s midtown district and is in talks about a potential deal in west midtown
#
# Actual Summary:
# wework seeks suburban locations in atlanta
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# a structural revolution is underway in the property sector according to jamie hopkins ceo of serviced and flexible office operator workspace the speed of advancements in technology mean that companies don t know where they will be in five years time prompting even the largest property companies such as british land to adopt the flexible and co working office business model made popular across the globe by wework
#
# Actual Summary:
# tech advancements driving office revolution
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# petrofac reported a 2 drop in net full year profits after booking an exceptional impairment charge of 79m largely related to greater stella near aberdeen which it sold last year the company is well positioned for 2019 with good revenue visibility and a healthy tender pipeline according to ceo ayman asfari
#
# Actual Summary:
# petrofac fy profits hit by greater stella impairment charge
#
# Created Summary:
# wework to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# a seven hour outage at yahoo mail on 5 september hit customers of talktalk bt and sky which rely on the platform to power their email services the technical issue started around 7am and continued into the afternoon
#
# Actual Summary:
# talktalk customers hit by yahoo mail outage
#
# Created Summary:
# wework to to to to in
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# despite significant pull outs from pandora parent soundexchange s h1 royalty payments increased 17 5 yoy the company s q2 results showed it made 208 7m in payments to artists and rights holders up from 177 6m a year earlier the music streaming service also saw its membership expand with the number of represented rights owners rising 9 to 28 065 in the three months through june
#
# Actual Summary:
# soundexchange royalty payouts increase 17 5 in h1
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# spaces has opened its inaugural co working centre in prague a 3 500 sq ft facility located in the former albatross building situated on n rodn tr da and na per t ne street a second location is planned in karl n s nile house and sm choff complex in sm chov the 15 000 sqm centre which is due to open in the coming months will make spaces the largest co workspace operator in the czech republic
#
# Actual Summary:
# spaces launches in czech republic aims to be country s largest co workspace operator within months
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# a recent report from instant group shows that whilst wework is grabbing headlines it is not grabbing market share in the uk the data shows that wework failed to reach 1 of the uk market and is easily outpaced by northern serviced office operator bruntwood even in london wework has a market share of just 2
#
# Actual Summary:
# bruntwood outpaces wework in uk marketshare
#
# Created Summary:
# wework to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# redrow homes donated the final 400 of a 1 000 fundraising effort by the young pta at st wilfrid s catholic primary school in hartford to buy a defibrillator set up four year s ago the young pta raises funds for various causes it is made up of children between the ages of five and 11 and a small group of youth leaders aged 11 14 the oliver king foundation was chosen as its cause this year following a visit from the father of 12 year old oliver king who died from sudden arrhythmic death syndrome while taking part in a swimming race
#
# Actual Summary:
# redrow funds final 400 of fundraising to buy school a defibrillator
#
# Created Summary:
# redrow homes final 400 300 fundraising in concrete school a defibrillator
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# kingfisher has launched goodhome by b q a new international brand that will offer a simpler and more modern way to shop for home improvement projects a concept store has opened in wallington in the london borough of sutton staffed with a team offering expert advice and affordable solutions the smaller sized stores core range of 6 000 products will be available for same day delivery with an extended range of more 20 000 than products available for next day delivery
#
# Actual Summary:
# kingfisher launches smaller more modern b q brand
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# mightyhive has opened an office in tokyo the move will enable the company to extend sales and service of its integrated programmatic buying and analytics into japan a key area of growth in the market the s4 capital unit plans to hire 25 full time staff in the office by the end of the year it already has offices in singapore sydney and auckland
#
# Actual Summary:
# mightyhive expands asia network with tokyo opening
#
# Created Summary:
# china s to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# jpmorgan chase is taking space in albany s newest co working venue becoming capcity coworks first member tenant at the 11 north pearl street location the bank will use the space as a base for the operation of its training sessions with a staff of 30 employees as it continues to expand in new york state s capital city
#
# Actual Summary:
# jpmorgan chase signs up for co working space in albany
#
# Created Summary:
# china to to to to for
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# redrow is set to reveal the final phase of its buckshaw village housing project the finsbury style show home at west point will be unveiled on saturday 6 may to mark the end of the lancashire development west point will complete redrow s share of the location with just 21 new homes
#
# Actual Summary:
# redrow to reveal the final phase of its buckshaw village housing project in lancashire
#
# Created Summary:
# wework to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# cowork tahoe formerly tahoe mountain lab has completed a 1 100 sq ft expansion the company which launched in 2014 was the first to open at the lake and has since been joined by several other co workspace operators many of its tenants are companies from san francisco s bay area that want the tahoe lifestyle but holiday makers who have to work during their vacations are also clients of the company
#
# Actual Summary:
# cowork tahoe adds 1 100 sq ft to lakeside venue
#
# Created Summary:
# china to to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# the seventh lithium mine in western australia the pilgangoora has been opened by altura mining it is expected to produce 220 000 tonnes of lithium spodumene concentrate each year and production could double if needed to meet growing demand for batteries the company said last year lithium sales from the state reached aud780m 560m the pilgangoora deposit has reserves estimated at 41 1 million tonnes the lithium will be taken to port headland for export however the state government s lithium and energy materials industry taskforce is exploring how western australia could process lithium as well as produce it
#
# Actual Summary:
# australia s altura mulling doubling output at new lithium mine
#
# Created Summary:
# australia s altura mulling doubling output for to lithium
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# vodafone gigafast has begun delivery of its full fibre service in aberdeen its second location so far 1 367 premises have been connected doubling the fttp footprint in the city from 1 11 to 2 25 vodafone and cityfibre are targeting one million premises with their network and expect to speed up delivery once it goes live in at least half a dozen areas
#
# Actual Summary:
# vodafone rolls out full fibre in aberdeen
#
# Created Summary:
# china s to to to to
#
#
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# cocowork and uob have set up cocowork uob plaza at the bank s headquarters in jakarta sme and start up customers of the bank will be offered discounted rates on office space helping them establish their operations quickly and cost effectively while cocowork s customers will be offered loans and trade financing to help them manage their businesses as well as the opportunity to access alternative financing options through uob s partnerships with ourcrowd an equity crowdfunding platform and venture capital firm innoven capital uob has also partnered with other co workspace providers across southeast asia such as common ground worq and toong
#
# Actual Summary:
# cocowork partners uob indonesia
#
# Created Summary:
# cocowork partners uob indonesia
